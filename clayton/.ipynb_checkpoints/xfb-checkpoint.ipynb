# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import optuna
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, log_loss
import xgboost as xgb
import seaborn as sns

# %%
data = pd.read_csv("Y:/departments/research_and_development/baseball_operations/clayton_goodiez/csv/2021_data.csv")
data_2022 = pd.read_csv("Y:/departments/research_and_development/baseball_operations/clayton_goodiez/csv/2022_data.csv")
data_2023 = pd.read_csv("Y:/departments/research_and_development/baseball_operations/clayton_goodiez/csv/2023_MLB_Seaspm.csv")
height_df = pd.read_csv("Y:/departments/research_and_development/baseball_operations/clayton_goodiez/csv/player_heights.csv")

# %%
testing_data = pd.concat([data_2022, data_2023], axis=0)

# %%
testing_data['description'].unique()
# Out:
# array(['hit_into_play', 'ball', 'foul_bunt', 'blocked_ball',
#        'swinging_strike', 'foul', 'called_strike', 'foul_tip',
#        'hit_by_pitch', 'swinging_strike_blocked', 'missed_bunt',
#        'pitchout', 'bunt_foul_tip', 'unknown_strike'], dtype=object)

# %%
def preprocess_data(df, height_df):
    """
    This function takes a DataFrame and applies several preprocessing steps to it.
    """
    # Define a function to condense pitch types
    def condense_pitch_type(pitch_type):
        if pitch_type == "FF":
            return "FF"
        elif pitch_type == "FT":
            return "SI"
        elif pitch_type == "FC":
            return "CT"
        elif pitch_type in ["SL", "ST", "SV"]:
            return "SL"
        elif pitch_type in ["CH", "FS"]:
            return "CH"
        elif pitch_type in ["CU", "KC", "CS"]:
            return "CB"
        elif pitch_type == "SI":
            return "SI"
        elif pitch_type == "KN":
            return "KN"
        else:
            return "FAHCK"
    # Define a function to determine if the pitch resulted in a swing
    def is_contact(description):
        return 1 if description in ["foul_tip", "foul_bunt", "foul", 
                                "foul_pitchout", "hit_into_play", 
                                "hit_into_play_no_out", "hit_into_play_score", 
                                "pitchout_hit_into_play_score", 'hit_into_play'] else 0 
    
    def create_pitch_id(df):
        df['pitch_id_raw'] = (df['game_pk'].astype(str) + "_" +
                          df['batter'].astype(str) + "_" +
                          df['pitcher'].astype(str) + "_" +
                          df['pitch_number'].astype(str) + "_" +
                          df['at_bat_number'].astype(str) + "_" +
                          df['inning'].astype(str))
        return df
    # Define a function to determine if the pitch resulted in a fly ball
    def is_fly_ball(bb_type):
        return 1 if bb_type == "fly_ball" else 0

    df['pitch_type_condensed'] = df['pitch_type'].apply(condense_pitch_type)

    # Calculate 'release_pos_y'
    df['release_pos_y'] = 60.5 - df['release_extension']


    df['contact'] = df['description'].apply(is_contact)


    df['fb'] = df['bb_type'].apply(is_fly_ball)

    # Create 'pitch_id_raw'
    df = create_pitch_id(df)

    dfs = df.merge(height_df[['id', 'height_numeric']], how='left', left_on='pitcher', right_on='id')
    # Return the preprocessed DataFrame
    return dfs

# %%
# Apply the function to the 'pitch_type' column
data_processed = preprocess_data(data, height_df)# Use the query method to filter rows where 'swing' is 1 and 'pitch_type_condensed' is 'FF', 'SI', or 'CT'
training_data = data_processed.query('contact == 1')
testing_data_processed = preprocess_data(testing_data, height_df)

# %%
fastball_training = training_data.query('pitch_type_condensed in ("FF", "SI", "CT")')
fastball_testing = testing_data_processed.query('pitch_type_condensed in ("FF", "SI", "CT")')
breaking_ball = training_data.query('pitch_type_condensed in ("SL", "CB")')
breaking_ball_testing = testing_data_processed.query('pitch_type_condensed in ("SL", "CB")')

# %% [markdown]
# # Fastball Model First

# %%
# Now, separate features and identifiers
training_identifiers = fastball_training[['pitch_id_raw']]
testing_identifiers = fastball_testing[['pitch_id_raw']]
training_features = fastball_training.drop(columns=[
    'description', 'events', 'game_pk', 'game_date', 'des', 'zone', 'stand', 'p_throws',
    'spin_rate_deprecated', 'break_angle_deprecated', 'break_length_deprecated', 
    'game_type', 'home_team', 'away_team', 'type', 'bb_type', 'inning_topbot', 
    'hc_x', 'hc_y', 'tfs_deprecated', 'tfs_zulu_deprecated', 'hit_distance_sc', 
    'launch_speed', 'launch_angle', 'estimated_ba_using_speedangle', 'contact',
    'estimated_woba_using_speedangle', 'woba_value', 'woba_denom', 'babip_value', 
    'iso_value', 'launch_speed_angle', 'pitch_name', 'home_score', 'away_score', 
    'bat_score', 'fld_score', 'post_away_score', 'post_home_score', 'post_bat_score', 
    'post_fld_score', 'if_fielding_alignment', 'of_fielding_alignment', 
    'delta_home_win_exp', 'delta_run_exp', 'player_name', 'hit_location', 'umpire', 
    'sv_id', 'spin_dir', 'pitch_type', 'fielder_2.1', 'pitcher.1', 'fielder_3', 
    'fielder_4', 'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8', 'fielder_9', 
    'batter', 'pitcher', 'on_3b', 'on_2b', 'on_1b', 'game_year', 'outs_when_up', 
    'pitch_number', 'at_bat_number', 'inning', 'fielder_2', 'sz_top', 'sz_bot',
    'pitch_id_raw', 'effective_speed', 'p_throws', 'id', 'pitch_type_condensed',
    'plate_x', 'plate_z'
], axis=1)
testing_features = fastball_testing.drop(columns=[
    'description', 'events', 'game_pk', 'game_date', 'des', 'zone', 'stand', 'p_throws',
    'spin_rate_deprecated', 'break_angle_deprecated', 'break_length_deprecated', 
    'game_type', 'home_team', 'away_team', 'type', 'bb_type', 'inning_topbot', 
    'hc_x', 'hc_y', 'tfs_deprecated', 'tfs_zulu_deprecated', 'hit_distance_sc', 
    'launch_speed', 'launch_angle', 'estimated_ba_using_speedangle', 'contact',
    'estimated_woba_using_speedangle', 'woba_value', 'woba_denom', 'babip_value', 
    'iso_value', 'launch_speed_angle', 'pitch_name', 'home_score', 'away_score', 
    'bat_score', 'fld_score', 'post_away_score', 'post_home_score', 'post_bat_score', 
    'post_fld_score', 'if_fielding_alignment', 'of_fielding_alignment', 
    'delta_home_win_exp', 'delta_run_exp', 'player_name', 'hit_location', 'umpire', 
    'sv_id', 'spin_dir', 'pitch_type', 'fielder_2.1', 'pitcher.1', 'fielder_3', 
    'fielder_4', 'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8', 'fielder_9', 
    'batter', 'pitcher', 'on_3b', 'on_2b', 'on_1b', 'game_year', 'outs_when_up', 
    'pitch_number', 'at_bat_number', 'inning', 'fielder_2', 'sz_top', 'sz_bot',
    'pitch_id_raw', 'effective_speed', 'p_throws', 'id', 'pitch_type_condensed',
    'plate_x', 'plate_z', 'Unnamed: 0'
], axis=1)   # Exclude the identifier from the features

# %%
train_data = training_features.drop(['fb'], axis=1).copy()
train_label = training_features['fb'].copy()
testing_data = testing_features.drop(['fb'], axis=1).copy()
testing_label = testing_features['fb'].copy()

# %%
train_data.columns
# Out:
# Index(['release_speed', 'release_pos_x', 'release_pos_z', 'balls', 'strikes',
#        'pfx_x', 'pfx_z', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az',
#        'release_spin_rate', 'release_extension', 'release_pos_y', 'spin_axis',
#        'height_numeric'],
#       dtype='object')

# %%
testing_data.columns
# Out:
# Index(['release_speed', 'release_pos_x', 'release_pos_z', 'balls', 'strikes',
#        'pfx_x', 'pfx_z', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az',
#        'release_spin_rate', 'release_extension', 'release_pos_y', 'spin_axis',
#        'height_numeric'],
#       dtype='object')

# %%
# First split: Separate out a portion of the data as a temporary test set
x_temp, x_test, y_temp, y_test = train_test_split(
    train_data, 
    train_label, 
    test_size=0.2, 
    random_state=42
)

# Second split: Split the temporary test set into validation and test sets
x_train, x_valid, y_train, y_valid = train_test_split(
    x_temp, 
    y_temp, 
    test_size=0.25,
    random_state=42
)

# %%
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test, label=y_test)
class_ratio = y_train.value_counts()[0] / y_train.value_counts()[1]
params = {
    'max_depth': 6,
    'eta': 0.1,
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'subsample': 0.9,
    'colsample_bytree': 1,
    'scale_pos_weight': class_ratio,
}

# Initial Model
model = xgb.train(params, dtrain)

# %%
# Generate predictions
y_pred = model.predict(dtest)
y_pred_binary = [1 if p >= 0.5 else 0 for p in y_pred]

# Calculate Accuracy
accuracy = accuracy_score(y_test, y_pred_binary)
print(f"Accuracy: {accuracy}")

# Calculate Log Loss
logloss = log_loss(y_test, y_pred)
print(f"Log Loss: {logloss}")
# Out:
# Accuracy: 0.5340652543683315
# Log Loss: 0.6768003369576615

# %%
xgb.plot_importance(model)
plt.show()

# %%
# Convert predicted probabilities to binary predictions
y_pred_binary = [1 if p >= 0.5 else 0 for p in y_pred]

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred_binary)

# Plot the confusion matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Flyball', 'Flyball'], yticklabels=['Not Flyball', 'Flyball'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# # Initial Paramater Tuning

# %%
def objective(trial):
    dtrain = xgb.DMatrix(x_train, label=y_train)
    dvalid = xgb.DMatrix(x_valid, label=y_valid)
    
    param = {
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'eta': trial.suggest_float('eta', 0.01, 0.3),
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'subsample': trial.suggest_float('subsample', 0.6, 0.9),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1),
        'scale_pos_weight': class_ratio
    }

    # Train the model with early stopping
    model = xgb.train(
        param, 
        dtrain, 
        num_boost_round=100,  # Maximum number of boosting rounds
        evals=[(dvalid, 'eval')],  # Validation set for early stopping
        early_stopping_rounds=50  # Stop if the eval metric doesn't improve for 50 rounds
    )
    
    # Predict on the validation set using the best iteration
    y_valid_pred = model.predict(dvalid)
    
    # Calculate the log loss on the validation set
    loss = log_loss(y_valid, y_valid_pred)

    return loss

# %%
#create an optuna study and specifcy the the direction of the optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1000)
# Out:
# [I 2023-11-09 16:28:35,428] A new study created in memory with name: no-name-f2091d72-a894-4c6f-ae06-cf66f16bf74a
# [0]	eval-logloss:0.69055
# [1]	eval-logloss:0.68787
# [2]	eval-logloss:0.68694
# [3]	eval-logloss:0.68611
# [4]	eval-logloss:0.68486
# [5]	eval-logloss:0.68450
# [6]	eval-logloss:0.68370
# [7]	eval-logloss:0.68344
# [8]	eval-logloss:0.68197
# [9]	eval-logloss:0.68099
# [10]	eval-logloss:0.68053
# [11]	eval-logloss:0.68034
# [12]	eval-logloss:0.68016
# [13]	eval-logloss:0.68064
# [14]	eval-logloss:0.68055
# [15]	eval-logloss:0.68037
# [16]	eval-logloss:0.67999
# [17]	eval-logloss:0.67945
# [18]	eval-logloss:0.67970
# [19]	eval-logloss:0.67927
# [20]	eval-logloss:0.67882
# [21]	eval-logloss:0.67893
# [22]	eval-logloss:0.67918
# [23]	eval-logloss:0.67884
# [24]	eval-logloss:0.67974
# [25]	eval-logloss:0.68030
# [26]	eval-logloss:0.67938
# [27]	eval-logloss:0.67863
# [28]	eval-logloss:0.67851
# [29]	eval-logloss:0.67829
# [30]	eval-logloss:0.67724
# [31]	eval-logloss:0.67726
# [32]	eval-logloss:0.67728
# [33]	eval-logloss:0.67695
# [34]	eval-logloss:0.67724
# [35]	eval-logloss:0.67698
# [36]	eval-logloss:0.67665
# [37]	eval-logloss:0.67602
# [38]	eval-logloss:0.67619
# [39]	eval-logloss:0.67516
# [40]	eval-logloss:0.67545
# [41]	eval-logloss:0.67604
# [42]	eval-logloss:0.67580
# [43]	eval-logloss:0.67550
# [44]	eval-logloss:0.67529
# [45]	eval-logloss:0.67546
# [46]	eval-logloss:0.67458
# [47]	eval-logloss:0.67447
# [48]	eval-logloss:0.67501
# [49]	eval-logloss:0.67464
# [50]	eval-logloss:0.67396
# [51]	eval-logloss:0.67349
# [52]	eval-logloss:0.67295
# [53]	eval-logloss:0.67226
# [54]	eval-logloss:0.67262
# [55]	eval-logloss:0.67211
# [56]	eval-logloss:0.67207
# [57]	eval-logloss:0.67191
# [58]	eval-logloss:0.67223
# [59]	eval-logloss:0.67204
# [60]	eval-logloss:0.67215
# [61]	eval-logloss:0.67277
# [62]	eval-logloss:0.67284
# [63]	eval-logloss:0.67330
# [64]	eval-logloss:0.67365
# [65]	eval-logloss:0.67289
# [66]	eval-logloss:0.67205
# [67]	eval-logloss:0.67194
# [68]	eval-logloss:0.67245
# [69]	eval-logloss:0.67275
# [70]	eval-logloss:0.67221
# [71]	eval-logloss:0.67176
# [72]	eval-logloss:0.67178
# [73]	eval-logloss:0.67194
# [74]	eval-logloss:0.67205
# [75]	eval-logloss:0.67202
# [76]	eval-logloss:0.67143
# [77]	eval-logloss:0.67094
# [78]	eval-logloss:0.67132
# [79]	eval-logloss:0.67169
# [80]	eval-logloss:0.67131
# [81]	eval-logloss:0.67126
# [82]	eval-logloss:0.67183
# [83]	eval-logloss:0.67179
# [84]	eval-logloss:0.67122
# [85]	eval-logloss:0.67126
# [86]	eval-logloss:0.67065
# [87]	eval-logloss:0.67055
# [88]	eval-logloss:0.67062
# [89]	eval-logloss:0.67139
# [90]	eval-logloss:0.67117
# [91]	eval-logloss:0.67128
# [92]	eval-logloss:0.67087
# [93]	eval-logloss:0.67051
# [94]	eval-logloss:0.66958
# [95]	eval-logloss:0.66936
# [96]	eval-logloss:0.67009
# [97]	eval-logloss:0.67064
# [98]	eval-logloss:0.67145
# [99]	eval-logloss:0.67127
# [I 2023-11-09 16:28:36,821] Trial 0 finished with value: 0.6712675703071345 and parameters: {'max_depth': 3, 'eta': 0.24278961962135812, 'subsample': 0.7952068851221762, 'colsample_bytree': 0.7198516727337829}. Best is trial 0 with value: 0.6712675703071345.
# [0]	eval-logloss:0.69226
# [1]	eval-logloss:0.69098
# [2]	eval-logloss:0.69006
# [3]	eval-logloss:0.68890
# [4]	eval-logloss:0.68789
# [5]	eval-logloss:0.68697
# [6]	eval-logloss:0.68612
# [7]	eval-logloss:0.68563
# [8]	eval-logloss:0.68500
# [9]	eval-logloss:0.68434
# [10]	eval-logloss:0.68353
# [11]	eval-logloss:0.68286
# [12]	eval-logloss:0.68226
# [13]	eval-logloss:0.68193
# [14]	eval-logloss:0.68154
# [15]	eval-logloss:0.68113
# [16]	eval-logloss:0.68067
# [17]	eval-logloss:0.68005
# [18]	eval-logloss:0.67965
# [19]	eval-logloss:0.67919
# [20]	eval-logloss:0.67879
# [21]	eval-logloss:0.67847
# [22]	eval-logloss:0.67818
# [23]	eval-logloss:0.67777
# [24]	eval-logloss:0.67758
# [25]	eval-logloss:0.67742
# [26]	eval-logloss:0.67709
# [27]	eval-logloss:0.67674
# [28]	eval-logloss:0.67643
# [29]	eval-logloss:0.67620
# [30]	eval-logloss:0.67581
# [31]	eval-logloss:0.67553
# [32]	eval-logloss:0.67535
# [33]	eval-logloss:0.67531
# [34]	eval-logloss:0.67502
# [35]	eval-logloss:0.67486
# [36]	eval-logloss:0.67475
# [37]	eval-logloss:0.67442
# [38]	eval-logloss:0.67434
# [39]	eval-logloss:0.67422
# [40]	eval-logloss:0.67410
# [41]	eval-logloss:0.67399
# [42]	eval-logloss:0.67379
# [43]	eval-logloss:0.67354
# [44]	eval-logloss:0.67336
# [45]	eval-logloss:0.67323
# [46]	eval-logloss:0.67304
# [47]	eval-logloss:0.67280
# [48]	eval-logloss:0.67281
# [49]	eval-logloss:0.67259
# [50]	eval-logloss:0.67247
# [51]	eval-logloss:0.67219
# [52]	eval-logloss:0.67205
# [53]	eval-logloss:0.67171
# [54]	eval-logloss:0.67158
# [55]	eval-logloss:0.67143
# [56]	eval-logloss:0.67135
# [57]	eval-logloss:0.67134
# [58]	eval-logloss:0.67116
# [59]	eval-logloss:0.67107
# [60]	eval-logloss:0.67095
# [61]	eval-logloss:0.67087
# [62]	eval-logloss:0.67061
# [63]	eval-logloss:0.67045
# [64]	eval-logloss:0.67038
# [65]	eval-logloss:0.67011
# [66]	eval-logloss:0.67004
# [67]	eval-logloss:0.66988
# [68]	eval-logloss:0.67000
# [69]	eval-logloss:0.66997
# [70]	eval-logloss:0.66999
# [71]	eval-logloss:0.66996
# [72]	eval-logloss:0.66981
# [73]	eval-logloss:0.66958
# [74]	eval-logloss:0.66942
# [75]	eval-logloss:0.66933
# [76]	eval-logloss:0.66902
# [77]	eval-logloss:0.66881
# [78]	eval-logloss:0.66882
# [79]	eval-logloss:0.66884
# [80]	eval-logloss:0.66875
# [81]	eval-logloss:0.66867
# [82]	eval-logloss:0.66870
# [83]	eval-logloss:0.66861
# [84]	eval-logloss:0.66853
# [85]	eval-logloss:0.66853
# [86]	eval-logloss:0.66835
# [87]	eval-logloss:0.66824
# [88]	eval-logloss:0.66815
# [89]	eval-logloss:0.66820
# [90]	eval-logloss:0.66805
# [91]	eval-logloss:0.66796
# [92]	eval-logloss:0.66783
# [93]	eval-logloss:0.66754
# [94]	eval-logloss:0.66727
# [95]	eval-logloss:0.66715
# [96]	eval-logloss:0.66722
# [97]	eval-logloss:0.66725
# [98]	eval-logloss:0.66722
# [99]	eval-logloss:0.66703
# [I 2023-11-09 16:28:38,429] Trial 1 finished with value: 0.6670266081184248 and parameters: {'max_depth': 5, 'eta': 0.0672799464611078, 'subsample': 0.8691173342007809, 'colsample_bytree': 0.5527230090884787}. Best is trial 0 with value: 0.6712675703071345.
# [0]	eval-logloss:0.68571
# [1]	eval-logloss:0.68070
# [2]	eval-logloss:0.67709
# [3]	eval-logloss:0.67347
# [4]	eval-logloss:0.67047
# [5]	eval-logloss:0.66778
# [6]	eval-logloss:0.66562
# [7]	eval-logloss:0.66359
# [8]	eval-logloss:0.66134
# [9]	eval-logloss:0.65914
# [10]	eval-logloss:0.65720
# [11]	eval-logloss:0.65495
# [12]	eval-logloss:0.65389
# [13]	eval-logloss:0.65293
# [14]	eval-logloss:0.65144
# [15]	eval-logloss:0.65064
# [16]	eval-logloss:0.64894
# [17]	eval-logloss:0.64712
# [18]	eval-logloss:0.64694
# [19]	eval-logloss:0.64522
# [20]	eval-logloss:0.64308
# [21]	eval-logloss:0.64237
# [22]	eval-logloss:0.64226
# [23]	eval-logloss:0.64088
# [24]	eval-logloss:0.63994
# [25]	eval-logloss:0.63959
# [26]	eval-logloss:0.63800
# [27]	eval-logloss:0.63682
# [28]	eval-logloss:0.63584
# [29]	eval-logloss:0.63510
# [30]	eval-logloss:0.63371
# [31]	eval-logloss:0.63338
# [32]	eval-logloss:0.63142
# [33]	eval-logloss:0.63112
# [34]	eval-logloss:0.63002
# [35]	eval-logloss:0.62912
# [36]	eval-logloss:0.62732
# [37]	eval-logloss:0.62650
# [38]	eval-logloss:0.62558
# [39]	eval-logloss:0.62429
# [40]	eval-logloss:0.62363
# [41]	eval-logloss:0.62321
# [42]	eval-logloss:0.62247
# [43]	eval-logloss:0.62183
# [44]	eval-logloss:0.62150
# [45]	eval-logloss:0.62143
# [46]	eval-logloss:0.62010
# [47]	eval-logloss:0.61989
# [48]	eval-logloss:0.61910
# [49]	eval-logloss:0.61790
# [50]	eval-logloss:0.61623
# [51]	eval-logloss:0.61532
# [52]	eval-logloss:0.61403
# [53]	eval-logloss:0.61232
# [54]	eval-logloss:0.61167
# [55]	eval-logloss:0.61051
# [56]	eval-logloss:0.60996
# [57]	eval-logloss:0.60926
# [58]	eval-logloss:0.60872
# [59]	eval-logloss:0.60717
# [60]	eval-logloss:0.60644
# [61]	eval-logloss:0.60626
# [62]	eval-logloss:0.60543
# [63]	eval-logloss:0.60549
# [64]	eval-logloss:0.60499
# [65]	eval-logloss:0.60369
# [66]	eval-logloss:0.60286
# [67]	eval-logloss:0.60209
# [68]	eval-logloss:0.60208
# [69]	eval-logloss:0.60162
# [70]	eval-logloss:0.60107
# [71]	eval-logloss:0.60027
# [72]	eval-logloss:0.59992
# [73]	eval-logloss:0.59911
# [74]	eval-logloss:0.59866
# [75]	eval-logloss:0.59779
# [76]	eval-logloss:0.59676
# [77]	eval-logloss:0.59541
# [78]	eval-logloss:0.59511
# [79]	eval-logloss:0.59437
# [80]	eval-logloss:0.59350
# [81]	eval-logloss:0.59322
# [82]	eval-logloss:0.59266
# [83]	eval-logloss:0.59181
# [84]	eval-logloss:0.59121
# [85]	eval-logloss:0.59090
# [86]	eval-logloss:0.58960
# [87]	eval-logloss:0.58913
# [88]	eval-logloss:0.58814
# [89]	eval-logloss:0.58782
# [90]	eval-logloss:0.58727
# [91]	eval-logloss:0.58699
# [92]	eval-logloss:0.58607
# [93]	eval-logloss:0.58570
# [94]	eval-logloss:0.58498
# [95]	eval-logloss:0.58378
# [96]	eval-logloss:0.58253
# [97]	eval-logloss:0.58236
# [98]	eval-logloss:0.58265
# [99]	eval-logloss:0.58187
# [I 2023-11-09 16:28:40,413] Trial 2 finished with value: 0.5818662386872374 and parameters: {'max_depth': 8, 'eta': 0.16845339736034792, 'subsample': 0.7817598905419496, 'colsample_bytree': 0.9698716740872593}. Best is trial 0 with value: 0.6712675703071345.
# [0]	eval-logloss:0.68920
# [1]	eval-logloss:0.68479
# [2]	eval-logloss:0.68382
# [3]	eval-logloss:0.68243
# [4]	eval-logloss:0.68082
# [5]	eval-logloss:0.67979
# [6]	eval-logloss:0.67900
# [7]	eval-logloss:0.67820
# [8]	eval-logloss:0.67560
# [9]	eval-logloss:0.67439
# [10]	eval-logloss:0.67347
# [11]	eval-logloss:0.67414
# [12]	eval-logloss:0.67332
# [13]	eval-logloss:0.67380
# [14]	eval-logloss:0.67348
# [15]	eval-logloss:0.67309
# [16]	eval-logloss:0.67154
# [17]	eval-logloss:0.67039
# [18]	eval-logloss:0.67072
# [19]	eval-logloss:0.67107
# [20]	eval-logloss:0.66974
# [21]	eval-logloss:0.66940
# [22]	eval-logloss:0.67005
# [23]	eval-logloss:0.67097
# [24]	eval-logloss:0.67118
# [25]	eval-logloss:0.67104
# [26]	eval-logloss:0.66925
# [27]	eval-logloss:0.66789
# [28]	eval-logloss:0.66906
# [29]	eval-logloss:0.66913
# [30]	eval-logloss:0.66811
# [31]	eval-logloss:0.66845
# [32]	eval-logloss:0.66626
# [33]	eval-logloss:0.66637
# [34]	eval-logloss:0.66587
# [35]	eval-logloss:0.66481
# [36]	eval-logloss:0.66456
# [37]	eval-logloss:0.66409
# [38]	eval-logloss:0.66429
# [39]	eval-logloss:0.66256
# [40]	eval-logloss:0.66311
# [41]	eval-logloss:0.66451
# [42]	eval-logloss:0.66402
# [43]	eval-logloss:0.66388
# [44]	eval-logloss:0.66390
# [45]	eval-logloss:0.66405
# [46]	eval-logloss:0.66247
# [47]	eval-logloss:0.66248
# [48]	eval-logloss:0.66142
# [49]	eval-logloss:0.66111
# [50]	eval-logloss:0.66052
# [51]	eval-logloss:0.66024
# [52]	eval-logloss:0.65925
# [53]	eval-logloss:0.65761
# [54]	eval-logloss:0.65766
# [55]	eval-logloss:0.65632
# [56]	eval-logloss:0.65593
# [57]	eval-logloss:0.65574
# [58]	eval-logloss:0.65573
# [59]	eval-logloss:0.65511
# [60]	eval-logloss:0.65403
# [61]	eval-logloss:0.65456
# [62]	eval-logloss:0.65591
# [63]	eval-logloss:0.65604
# [64]	eval-logloss:0.65673
# [65]	eval-logloss:0.65524
# [66]	eval-logloss:0.65394
# [67]	eval-logloss:0.65412
# [68]	eval-logloss:0.65464
# [69]	eval-logloss:0.65476
# [70]	eval-logloss:0.65407
# [71]	eval-logloss:0.65421
# [72]	eval-logloss:0.65381
# [73]	eval-logloss:0.65392
# [74]	eval-logloss:0.65526
# [75]	eval-logloss:0.65425
# [76]	eval-logloss:0.65349
# [77]	eval-logloss:0.65259
# [78]	eval-logloss:0.65245
# [79]	eval-logloss:0.65236
# [80]	eval-logloss:0.65278
# [81]	eval-logloss:0.65302
# [82]	eval-logloss:0.65376
# [83]	eval-logloss:0.65294
# [84]	eval-logloss:0.65147
# [85]	eval-logloss:0.65148
# [86]	eval-logloss:0.65008
# [87]	eval-logloss:0.64978
# [88]	eval-logloss:0.64934
# [89]	eval-logloss:0.65066
# [90]	eval-logloss:0.65014
# [91]	eval-logloss:0.65098
# [92]	eval-logloss:0.65031
# [93]	eval-logloss:0.64968
# [94]	eval-logloss:0.64910
# [95]	eval-logloss:0.64919
# [96]	eval-logloss:0.64883
# [97]	eval-logloss:0.64934
# [98]	eval-logloss:0.64930
# [99]	eval-logloss:0.64878
# [I 2023-11-09 16:28:41,868] Trial 3 finished with value: 0.6487846266590703 and parameters: {'max_depth': 5, 'eta': 0.27260125223092124, 'subsample': 0.6445676405019425, 'colsample_bytree': 0.6394924845402086}. Best is trial 0 with value: 0.6712675703071345.
# [0]	eval-logloss:0.68139
# [1]	eval-logloss:0.67177
# [2]	eval-logloss:0.66540
# [3]	eval-logloss:0.65958
# [4]	eval-logloss:0.65529
# [5]	eval-logloss:0.65136
# [6]	eval-logloss:0.64854
# [7]	eval-logloss:0.64580
# [8]	eval-logloss:0.64482
# [9]	eval-logloss:0.64150
# [10]	eval-logloss:0.63845
# [11]	eval-logloss:0.63587
# [12]	eval-logloss:0.63380
# [13]	eval-logloss:0.63244
# [14]	eval-logloss:0.63187
# [15]	eval-logloss:0.63023
# [16]	eval-logloss:0.62668
# [17]	eval-logloss:0.62415
# [18]	eval-logloss:0.62139
# [19]	eval-logloss:0.61956
# [20]	eval-logloss:0.61635
# [21]	eval-logloss:0.61397
# [22]	eval-logloss:0.61329
# [23]	eval-logloss:0.61014
# [24]	eval-logloss:0.60808
# [25]	eval-logloss:0.60784
# [26]	eval-logloss:0.60622
# [27]	eval-logloss:0.60398
# [28]	eval-logloss:0.60075
# [29]	eval-logloss:0.59987
# [30]	eval-logloss:0.59721
# [31]	eval-logloss:0.59687
# [32]	eval-logloss:0.59511
# [33]	eval-logloss:0.59339
# [34]	eval-logloss:0.59145
# [35]	eval-logloss:0.58813
# [36]	eval-logloss:0.58726
# [37]	eval-logloss:0.58550
# [38]	eval-logloss:0.58412
# [39]	eval-logloss:0.58246
# [40]	eval-logloss:0.58004
# [41]	eval-logloss:0.57975
# [42]	eval-logloss:0.57822
# [43]	eval-logloss:0.57671
# [44]	eval-logloss:0.57533
# [45]	eval-logloss:0.57373
# [46]	eval-logloss:0.57158
# [47]	eval-logloss:0.56999
# [48]	eval-logloss:0.56986
# [49]	eval-logloss:0.56788
# [50]	eval-logloss:0.56649
# [51]	eval-logloss:0.56559
# [52]	eval-logloss:0.56449
# [53]	eval-logloss:0.56307
# [54]	eval-logloss:0.56218
# [55]	eval-logloss:0.56085
# [56]	eval-logloss:0.55918
# [57]	eval-logloss:0.55805
# [58]	eval-logloss:0.55716
# [59]	eval-logloss:0.55617
# [60]	eval-logloss:0.55515
# [61]	eval-logloss:0.55341
# [62]	eval-logloss:0.55200
# [63]	eval-logloss:0.55041
# [64]	eval-logloss:0.54946
# [65]	eval-logloss:0.54807
# [66]	eval-logloss:0.54636
# [67]	eval-logloss:0.54484
# [68]	eval-logloss:0.54382
# [69]	eval-logloss:0.54250
# [70]	eval-logloss:0.54187
# [71]	eval-logloss:0.54076
# [72]	eval-logloss:0.53981
# [73]	eval-logloss:0.53666
# [74]	eval-logloss:0.53625
# [75]	eval-logloss:0.53564
# [76]	eval-logloss:0.53415
# [77]	eval-logloss:0.53281
# [78]	eval-logloss:0.53190
# [79]	eval-logloss:0.53029
# [80]	eval-logloss:0.52903
# [81]	eval-logloss:0.52781
# [82]	eval-logloss:0.52716
# [83]	eval-logloss:0.52574
# [84]	eval-logloss:0.52482
# [85]	eval-logloss:0.52430
# [86]	eval-logloss:0.52364
# [87]	eval-logloss:0.52298
# [88]	eval-logloss:0.52255
# [89]	eval-logloss:0.52209
# [90]	eval-logloss:0.52147
# [91]	eval-logloss:0.52076
# [92]	eval-logloss:0.51963
# [93]	eval-logloss:0.51858
# [94]	eval-logloss:0.51770
# [95]	eval-logloss:0.51536
# [96]	eval-logloss:0.51481
# [97]	eval-logloss:0.51365
# [98]	eval-logloss:0.51297
# [99]	eval-logloss:0.51228
# [I 2023-11-09 16:28:44,161] Trial 4 finished with value: 0.5122756844552907 and parameters: {'max_depth': 9, 'eta': 0.29821377788341047, 'subsample': 0.862759874329621, 'colsample_bytree': 0.8357687630934744}. Best is trial 0 with value: 0.6712675703071345.
# [0]	eval-logloss:0.69218
# [1]	eval-logloss:0.69098
# [2]	eval-logloss:0.69015
# [3]	eval-logloss:0.68900
# [4]	eval-logloss:0.68804
# [5]	eval-logloss:0.68713
# [6]	eval-logloss:0.68612
# [7]	eval-logloss:0.68547
# [8]	eval-logloss:0.68448
# [9]	eval-logloss:0.68375
# [10]	eval-logloss:0.68294
# [11]	eval-logloss:0.68218
# [12]	eval-logloss:0.68138
# [13]	eval-logloss:0.68062
# [14]	eval-logloss:0.67988
# [15]	eval-logloss:0.67920
# [16]	eval-logloss:0.67858
# [17]	eval-logloss:0.67780
# [18]	eval-logloss:0.67706
# [19]	eval-logloss:0.67639
# [20]	eval-logloss:0.67580
# [21]	eval-logloss:0.67527
# [22]	eval-logloss:0.67457
# [23]	eval-logloss:0.67401
# [24]	eval-logloss:0.67350
# [25]	eval-logloss:0.67306
# [26]	eval-logloss:0.67253
# [27]	eval-logloss:0.67198
# [28]	eval-logloss:0.67149
# [29]	eval-logloss:0.67109
# [30]	eval-logloss:0.67045
# [31]	eval-logloss:0.67006
# [32]	eval-logloss:0.66955
# [33]	eval-logloss:0.66910
# [34]	eval-logloss:0.66867
# [35]	eval-logloss:0.66825
# [36]	eval-logloss:0.66792
# [37]	eval-logloss:0.66743
# [38]	eval-logloss:0.66697
# [39]	eval-logloss:0.66656
# [40]	eval-logloss:0.66613
# [41]	eval-logloss:0.66572
# [42]	eval-logloss:0.66525
# [43]	eval-logloss:0.66480
# [44]	eval-logloss:0.66439
# [45]	eval-logloss:0.66391
# [46]	eval-logloss:0.66358
# [47]	eval-logloss:0.66321
# [48]	eval-logloss:0.66285
# [49]	eval-logloss:0.66236
# [50]	eval-logloss:0.66192
# [51]	eval-logloss:0.66149
# [52]	eval-logloss:0.66111
# [53]	eval-logloss:0.66077
# [54]	eval-logloss:0.66053
# [55]	eval-logloss:0.66011
# [56]	eval-logloss:0.65978
# [57]	eval-logloss:0.65944
# [58]	eval-logloss:0.65903
# [59]	eval-logloss:0.65879
# [60]	eval-logloss:0.65845
# [61]	eval-logloss:0.65825
# [62]	eval-logloss:0.65782
# [63]	eval-logloss:0.65750
# [64]	eval-logloss:0.65725
# [65]	eval-logloss:0.65688
# [66]	eval-logloss:0.65657
# [67]	eval-logloss:0.65621
# [68]	eval-logloss:0.65590
# [69]	eval-logloss:0.65565
# [70]	eval-logloss:0.65530
# [71]	eval-logloss:0.65502
# [72]	eval-logloss:0.65472
# [73]	eval-logloss:0.65434
# [74]	eval-logloss:0.65397
# [75]	eval-logloss:0.65374
# [76]	eval-logloss:0.65347
# [77]	eval-logloss:0.65320
# [78]	eval-logloss:0.65285
# [79]	eval-logloss:0.65255
# [80]	eval-logloss:0.65228
# [81]	eval-logloss:0.65189
# [82]	eval-logloss:0.65165
# [83]	eval-logloss:0.65141
# [84]	eval-logloss:0.65112
# [85]	eval-logloss:0.65093
# [86]	eval-logloss:0.65059
# [87]	eval-logloss:0.65027
# [88]	eval-logloss:0.65015
# [89]	eval-logloss:0.64997
# [90]	eval-logloss:0.64984
# [91]	eval-logloss:0.64966
# [92]	eval-logloss:0.64942
# [93]	eval-logloss:0.64903
# [94]	eval-logloss:0.64873
# [95]	eval-logloss:0.64837
# [96]	eval-logloss:0.64826
# [97]	eval-logloss:0.64803
# [98]	eval-logloss:0.64802
# [99]	eval-logloss:0.64783
# [I 2023-11-09 16:28:46,285] Trial 5 finished with value: 0.6478332798273739 and parameters: {'max_depth': 8, 'eta': 0.027963896462648255, 'subsample': 0.8906655581787329, 'colsample_bytree': 0.6313056645446442}. Best is trial 0 with value: 0.6712675703071345.
# [0]	eval-logloss:0.69074
# [1]	eval-logloss:0.68864
# [2]	eval-logloss:0.68723
# [3]	eval-logloss:0.68583
# [4]	eval-logloss:0.68473
# [5]	eval-logloss:0.68392
# [6]	eval-logloss:0.68302
# [7]	eval-logloss:0.68241
# [8]	eval-logloss:0.68095
# [9]	eval-logloss:0.67983
# [10]	eval-logloss:0.67873
# [11]	eval-logloss:0.67811
# [12]	eval-logloss:0.67764
# [13]	eval-logloss:0.67734
# [14]	eval-logloss:0.67687
# [15]	eval-logloss:0.67662
# [16]	eval-logloss:0.67601
# [17]	eval-logloss:0.67567
# [18]	eval-logloss:0.67555
# [19]	eval-logloss:0.67543
# [20]	eval-logloss:0.67476
# [21]	eval-logloss:0.67457
# [22]	eval-logloss:0.67441
# [23]	eval-logloss:0.67416
# [24]	eval-logloss:0.67423
# [25]	eval-logloss:0.67424
# [26]	eval-logloss:0.67358
# [27]	eval-logloss:0.67294
# [28]	eval-logloss:0.67289
# [29]	eval-logloss:0.67244
# [30]	eval-logloss:0.67209
# [31]	eval-logloss:0.67224
# [32]	eval-logloss:0.67145
# [33]	eval-logloss:0.67121
# [34]	eval-logloss:0.67095
# [35]	eval-logloss:0.67031
# [36]	eval-logloss:0.66991
# [37]	eval-logloss:0.66950
# [38]	eval-logloss:0.66925
# [39]	eval-logloss:0.66822
# [40]	eval-logloss:0.66812
# [41]	eval-logloss:0.66831
# [42]	eval-logloss:0.66828
# [43]	eval-logloss:0.66817
# [44]	eval-logloss:0.66812
# [45]	eval-logloss:0.66794
# [46]	eval-logloss:0.66758
# [47]	eval-logloss:0.66745
# [48]	eval-logloss:0.66731
# [49]	eval-logloss:0.66681
# [50]	eval-logloss:0.66656
# [51]	eval-logloss:0.66642
# [52]	eval-logloss:0.66567
# [53]	eval-logloss:0.66529
# [54]	eval-logloss:0.66528
# [55]	eval-logloss:0.66498
# [56]	eval-logloss:0.66459
# [57]	eval-logloss:0.66383
# [58]	eval-logloss:0.66382
# [59]	eval-logloss:0.66328
# [60]	eval-logloss:0.66278
# [61]	eval-logloss:0.66282
# [62]	eval-logloss:0.66304
# [63]	eval-logloss:0.66303
# [64]	eval-logloss:0.66302
# [65]	eval-logloss:0.66221
# [66]	eval-logloss:0.66184
# [67]	eval-logloss:0.66183
# [68]	eval-logloss:0.66187
# [69]	eval-logloss:0.66189
# [70]	eval-logloss:0.66177
# [71]	eval-logloss:0.66188
# [72]	eval-logloss:0.66181
# [73]	eval-logloss:0.66184
# [74]	eval-logloss:0.66213
# [75]	eval-logloss:0.66161
# [76]	eval-logloss:0.66099
# [77]	eval-logloss:0.66073
# [78]	eval-logloss:0.66041
# [79]	eval-logloss:0.66047
# [80]	eval-logloss:0.66052
# [81]	eval-logloss:0.66054
# [82]	eval-logloss:0.66071
# [83]	eval-logloss:0.66056
# [84]	eval-logloss:0.66015
# [85]	eval-logloss:0.65992
# [86]	eval-logloss:0.65928
# [87]	eval-logloss:0.65901
# [88]	eval-logloss:0.65886
# [89]	eval-logloss:0.65911
# [90]	eval-logloss:0.65888
# [91]	eval-logloss:0.65914
# [92]	eval-logloss:0.65889
# [93]	eval-logloss:0.65846
# [94]	eval-logloss:0.65798
# [95]	eval-logloss:0.65778
# [96]	eval-logloss:0.65765
# [97]	eval-logloss:0.65782
# [98]	eval-logloss:0.65801
# [99]	eval-logloss:0.65775
# [I 2023-11-09 16:28:47,816] Trial 6 finished with value: 0.6577512499981097 and parameters: {'max_depth': 5, 'eta': 0.10871983147652646, 'subsample': 0.7048567114173598, 'colsample_bytree': 0.8242974265690863}. Best is trial 0 with value: 0.6712675703071345.
# [0]	eval-logloss:0.69069
# [1]	eval-logloss:0.68878
# [2]	eval-logloss:0.68726
# [3]	eval-logloss:0.68626
# [4]	eval-logloss:0.68532
# [5]	eval-logloss:0.68491
# [6]	eval-logloss:0.68424
# [7]	eval-logloss:0.68378
# [8]	eval-logloss:0.68301
# [9]	eval-logloss:0.68213
# [10]	eval-logloss:0.68166
# [11]	eval-logloss:0.68114
# [12]	eval-logloss:0.68092
# [13]	eval-logloss:0.68114
# [14]	eval-logloss:0.68070
# [15]	eval-logloss:0.68061
# [16]	eval-logloss:0.68014
# [17]	eval-logloss:0.67934
# [18]	eval-logloss:0.67934
# [19]	eval-logloss:0.67904
# [20]	eval-logloss:0.67871
# [21]	eval-logloss:0.67890
# [22]	eval-logloss:0.67886
# [23]	eval-logloss:0.67859
# [24]	eval-logloss:0.67839
# [25]	eval-logloss:0.67858
# [26]	eval-logloss:0.67840
# [27]	eval-logloss:0.67805
# [28]	eval-logloss:0.67785
# [29]	eval-logloss:0.67778
# [30]	eval-logloss:0.67725
# [31]	eval-logloss:0.67704
# [32]	eval-logloss:0.67708
# [33]	eval-logloss:0.67715
# [34]	eval-logloss:0.67703
# [35]	eval-logloss:0.67696
# [36]	eval-logloss:0.67686
# [37]	eval-logloss:0.67654
# [38]	eval-logloss:0.67661
# [39]	eval-logloss:0.67651
# [40]	eval-logloss:0.67654
# [41]	eval-logloss:0.67652
# [42]	eval-logloss:0.67639
# [43]	eval-logloss:0.67632
# [44]	eval-logloss:0.67627
# [45]	eval-logloss:0.67600
# [46]	eval-logloss:0.67561
# [47]	eval-logloss:0.67520
# [48]	eval-logloss:0.67536
# [49]	eval-logloss:0.67511
# [50]	eval-logloss:0.67522
# [51]	eval-logloss:0.67467
# [52]	eval-logloss:0.67454
# [53]	eval-logloss:0.67413
# [54]	eval-logloss:0.67429
# [55]	eval-logloss:0.67387
# [56]	eval-logloss:0.67389
# [57]	eval-logloss:0.67415
# [58]	eval-logloss:0.67413
# [59]	eval-logloss:0.67410
# [60]	eval-logloss:0.67384
# [61]	eval-logloss:0.67378
# [62]	eval-logloss:0.67349
# [63]	eval-logloss:0.67348
# [64]	eval-logloss:0.67346
# [65]	eval-logloss:0.67309
# [66]	eval-logloss:0.67276
# [67]	eval-logloss:0.67271
# [68]	eval-logloss:0.67307
# [69]	eval-logloss:0.67304
# [70]	eval-logloss:0.67301
# [71]	eval-logloss:0.67314
# [72]	eval-logloss:0.67296
# [73]	eval-logloss:0.67256
# [74]	eval-logloss:0.67215
# [75]	eval-logloss:0.67209
# [76]	eval-logloss:0.67175
# [77]	eval-logloss:0.67163
# [78]	eval-logloss:0.67158
# [79]	eval-logloss:0.67192
# [80]	eval-logloss:0.67192
# [81]	eval-logloss:0.67192
# [82]	eval-logloss:0.67219
# [83]	eval-logloss:0.67214
# [84]	eval-logloss:0.67204
# [85]	eval-logloss:0.67215
# [86]	eval-logloss:0.67183
# [87]	eval-logloss:0.67166
# [88]	eval-logloss:0.67161
# [89]	eval-logloss:0.67205
# [90]	eval-logloss:0.67189
# [91]	eval-logloss:0.67191
# [92]	eval-logloss:0.67184
# [93]	eval-logloss:0.67169
# [94]	eval-logloss:0.67113
# [95]	eval-logloss:0.67096
# [96]	eval-logloss:0.67128
# [97]	eval-logloss:0.67169
# [98]	eval-logloss:0.67165
# [99]	eval-logloss:0.67152
# [I 2023-11-09 16:28:49,085] Trial 7 finished with value: 0.6715199458807274 and parameters: {'max_depth': 3, 'eta': 0.16594201608338996, 'subsample': 0.8806168162457405, 'colsample_bytree': 0.9826886704280113}. Best is trial 7 with value: 0.6715199458807274.
# [0]	eval-logloss:0.68446
# [1]	eval-logloss:0.67561
# [2]	eval-logloss:0.67112
# [3]	eval-logloss:0.66544
# [4]	eval-logloss:0.66196
# [5]	eval-logloss:0.65900
# [6]	eval-logloss:0.65679
# [7]	eval-logloss:0.65443
# [8]	eval-logloss:0.64920
# [9]	eval-logloss:0.64720
# [10]	eval-logloss:0.64429
# [11]	eval-logloss:0.64295
# [12]	eval-logloss:0.64204
# [13]	eval-logloss:0.64184
# [14]	eval-logloss:0.63965
# [15]	eval-logloss:0.63859
# [16]	eval-logloss:0.63512
# [17]	eval-logloss:0.63219
# [18]	eval-logloss:0.63150
# [19]	eval-logloss:0.63091
# [20]	eval-logloss:0.62984
# [21]	eval-logloss:0.62806
# [22]	eval-logloss:0.62569
# [23]	eval-logloss:0.62559
# [24]	eval-logloss:0.62475
# [25]	eval-logloss:0.62319
# [26]	eval-logloss:0.62116
# [27]	eval-logloss:0.61901
# [28]	eval-logloss:0.61806
# [29]	eval-logloss:0.61648
# [30]	eval-logloss:0.61417
# [31]	eval-logloss:0.61410
# [32]	eval-logloss:0.61238
# [33]	eval-logloss:0.61211
# [34]	eval-logloss:0.61010
# [35]	eval-logloss:0.60804
# [36]	eval-logloss:0.60739
# [37]	eval-logloss:0.60685
# [38]	eval-logloss:0.60696
# [39]	eval-logloss:0.60423
# [40]	eval-logloss:0.60369
# [41]	eval-logloss:0.60356
# [42]	eval-logloss:0.60240
# [43]	eval-logloss:0.60046
# [44]	eval-logloss:0.59874
# [45]	eval-logloss:0.59824
# [46]	eval-logloss:0.59591
# [47]	eval-logloss:0.59443
# [48]	eval-logloss:0.59343
# [49]	eval-logloss:0.59233
# [50]	eval-logloss:0.59045
# [51]	eval-logloss:0.58965
# [52]	eval-logloss:0.58764
# [53]	eval-logloss:0.58518
# [54]	eval-logloss:0.58331
# [55]	eval-logloss:0.58296
# [56]	eval-logloss:0.58131
# [57]	eval-logloss:0.58051
# [58]	eval-logloss:0.57914
# [59]	eval-logloss:0.57871
# [60]	eval-logloss:0.57639
# [61]	eval-logloss:0.57566
# [62]	eval-logloss:0.57524
# [63]	eval-logloss:0.57505
# [64]	eval-logloss:0.57430
# [65]	eval-logloss:0.57255
# [66]	eval-logloss:0.57123
# [67]	eval-logloss:0.57051
# [68]	eval-logloss:0.57032
# [69]	eval-logloss:0.56993
# [70]	eval-logloss:0.56855
# [71]	eval-logloss:0.56719
# [72]	eval-logloss:0.56662
# [73]	eval-logloss:0.56667
# [74]	eval-logloss:0.56590
# [75]	eval-logloss:0.56369
# [76]	eval-logloss:0.56248
# [77]	eval-logloss:0.56103
# [78]	eval-logloss:0.55929
# [79]	eval-logloss:0.55875
# [80]	eval-logloss:0.55880
# [81]	eval-logloss:0.55757
# [82]	eval-logloss:0.55703
# [83]	eval-logloss:0.55538
# [84]	eval-logloss:0.55446
# [85]	eval-logloss:0.55460
# [86]	eval-logloss:0.55360
# [87]	eval-logloss:0.55246
# [88]	eval-logloss:0.55072
# [89]	eval-logloss:0.55034
# [90]	eval-logloss:0.54968
# [91]	eval-logloss:0.54917
# [92]	eval-logloss:0.54826
# [93]	eval-logloss:0.54776
# [94]	eval-logloss:0.54647
# [95]	eval-logloss:0.54592
# [96]	eval-logloss:0.54464
# [97]	eval-logloss:0.54431
# [98]	eval-logloss:0.54394
# [99]	eval-logloss:0.54381
# [I 2023-11-09 16:28:51,487] Trial 8 finished with value: 0.5438123053512313 and parameters: {'max_depth': 9, 'eta': 0.21438599030629527, 'subsample': 0.6982878354144345, 'colsample_bytree': 0.6150147485695644}. Best is trial 7 with value: 0.6715199458807274.
# [0]	eval-logloss:0.69258
# [1]	eval-logloss:0.69184
# [2]	eval-logloss:0.69134
# [3]	eval-logloss:0.69086
# [4]	eval-logloss:0.69029
# [5]	eval-logloss:0.68984
# [6]	eval-logloss:0.68935
# [7]	eval-logloss:0.68911
# [8]	eval-logloss:0.68847
# [9]	eval-logloss:0.68795
# [10]	eval-logloss:0.68758
# [11]	eval-logloss:0.68728
# [12]	eval-logloss:0.68697
# [13]	eval-logloss:0.68679
# [14]	eval-logloss:0.68652
# [15]	eval-logloss:0.68626
# [16]	eval-logloss:0.68601
# [17]	eval-logloss:0.68564
# [18]	eval-logloss:0.68550
# [19]	eval-logloss:0.68525
# [20]	eval-logloss:0.68500
# [21]	eval-logloss:0.68490
# [22]	eval-logloss:0.68478
# [23]	eval-logloss:0.68460
# [24]	eval-logloss:0.68460
# [25]	eval-logloss:0.68465
# [26]	eval-logloss:0.68438
# [27]	eval-logloss:0.68415
# [28]	eval-logloss:0.68403
# [29]	eval-logloss:0.68392
# [30]	eval-logloss:0.68360
# [31]	eval-logloss:0.68354
# [32]	eval-logloss:0.68333
# [33]	eval-logloss:0.68320
# [34]	eval-logloss:0.68308
# [35]	eval-logloss:0.68295
# [36]	eval-logloss:0.68281
# [37]	eval-logloss:0.68259
# [38]	eval-logloss:0.68254
# [39]	eval-logloss:0.68223
# [40]	eval-logloss:0.68212
# [41]	eval-logloss:0.68213
# [42]	eval-logloss:0.68200
# [43]	eval-logloss:0.68190
# [44]	eval-logloss:0.68183
# [45]	eval-logloss:0.68183
# [46]	eval-logloss:0.68159
# [47]	eval-logloss:0.68151
# [48]	eval-logloss:0.68149
# [49]	eval-logloss:0.68138
# [50]	eval-logloss:0.68116
# [51]	eval-logloss:0.68100
# [52]	eval-logloss:0.68074
# [53]	eval-logloss:0.68047
# [54]	eval-logloss:0.68042
# [55]	eval-logloss:0.68015
# [56]	eval-logloss:0.68002
# [57]	eval-logloss:0.67990
# [58]	eval-logloss:0.67985
# [59]	eval-logloss:0.67973
# [60]	eval-logloss:0.67960
# [61]	eval-logloss:0.67968
# [62]	eval-logloss:0.67966
# [63]	eval-logloss:0.67971
# [64]	eval-logloss:0.67979
# [65]	eval-logloss:0.67966
# [66]	eval-logloss:0.67949
# [67]	eval-logloss:0.67941
# [68]	eval-logloss:0.67943
# [69]	eval-logloss:0.67948
# [70]	eval-logloss:0.67946
# [71]	eval-logloss:0.67935
# [72]	eval-logloss:0.67936
# [73]	eval-logloss:0.67937
# [74]	eval-logloss:0.67934
# [75]	eval-logloss:0.67926
# [76]	eval-logloss:0.67912
# [77]	eval-logloss:0.67899
# [78]	eval-logloss:0.67895
# [79]	eval-logloss:0.67898
# [80]	eval-logloss:0.67890
# [81]	eval-logloss:0.67890
# [82]	eval-logloss:0.67901
# [83]	eval-logloss:0.67898
# [84]	eval-logloss:0.67887
# [85]	eval-logloss:0.67890
# [86]	eval-logloss:0.67870
# [87]	eval-logloss:0.67863
# [88]	eval-logloss:0.67857
# [89]	eval-logloss:0.67867
# [90]	eval-logloss:0.67861
# [91]	eval-logloss:0.67864
# [92]	eval-logloss:0.67856
# [93]	eval-logloss:0.67850
# [94]	eval-logloss:0.67830
# [95]	eval-logloss:0.67821
# [96]	eval-logloss:0.67829
# [97]	eval-logloss:0.67839
# [98]	eval-logloss:0.67857
# [99]	eval-logloss:0.67859
# [I 2023-11-09 16:28:52,904] Trial 9 finished with value: 0.678587772410527 and parameters: {'max_depth': 3, 'eta': 0.048476701550162545, 'subsample': 0.7834567460384115, 'colsample_bytree': 0.6868423337713594}. Best is trial 9 with value: 0.678587772410527.
# [0]	eval-logloss:0.69300
# [1]	eval-logloss:0.69282
# [2]	eval-logloss:0.69270
# [3]	eval-logloss:0.69253
# [4]	eval-logloss:0.69232
# [5]	eval-logloss:0.69212
# [6]	eval-logloss:0.69193
# [7]	eval-logloss:0.69181
# [8]	eval-logloss:0.69164
# [9]	eval-logloss:0.69149
# [10]	eval-logloss:0.69126
# [11]	eval-logloss:0.69108
# [12]	eval-logloss:0.69085
# [13]	eval-logloss:0.69072
# [14]	eval-logloss:0.69064
# [15]	eval-logloss:0.69050
# [16]	eval-logloss:0.69037
# [17]	eval-logloss:0.69021
# [18]	eval-logloss:0.69006
# [19]	eval-logloss:0.68994
# [20]	eval-logloss:0.68976
# [21]	eval-logloss:0.68962
# [22]	eval-logloss:0.68949
# [23]	eval-logloss:0.68938
# [24]	eval-logloss:0.68927
# [25]	eval-logloss:0.68915
# [26]	eval-logloss:0.68896
# [27]	eval-logloss:0.68879
# [28]	eval-logloss:0.68876
# [29]	eval-logloss:0.68867
# [30]	eval-logloss:0.68854
# [31]	eval-logloss:0.68846
# [32]	eval-logloss:0.68820
# [33]	eval-logloss:0.68809
# [34]	eval-logloss:0.68792
# [35]	eval-logloss:0.68779
# [36]	eval-logloss:0.68768
# [37]	eval-logloss:0.68755
# [38]	eval-logloss:0.68741
# [39]	eval-logloss:0.68719
# [40]	eval-logloss:0.68709
# [41]	eval-logloss:0.68708
# [42]	eval-logloss:0.68698
# [43]	eval-logloss:0.68686
# [44]	eval-logloss:0.68676
# [45]	eval-logloss:0.68668
# [46]	eval-logloss:0.68653
# [47]	eval-logloss:0.68646
# [48]	eval-logloss:0.68633
# [49]	eval-logloss:0.68623
# [50]	eval-logloss:0.68612
# [51]	eval-logloss:0.68600
# [52]	eval-logloss:0.68583
# [53]	eval-logloss:0.68568
# [54]	eval-logloss:0.68560
# [55]	eval-logloss:0.68545
# [56]	eval-logloss:0.68530
# [57]	eval-logloss:0.68515
# [58]	eval-logloss:0.68509
# [59]	eval-logloss:0.68500
# [60]	eval-logloss:0.68486
# [61]	eval-logloss:0.68476
# [62]	eval-logloss:0.68473
# [63]	eval-logloss:0.68467
# [64]	eval-logloss:0.68462
# [65]	eval-logloss:0.68451
# [66]	eval-logloss:0.68439
# [67]	eval-logloss:0.68432
# [68]	eval-logloss:0.68425
# [69]	eval-logloss:0.68416
# [70]	eval-logloss:0.68410
# [71]	eval-logloss:0.68402
# [72]	eval-logloss:0.68394
# [73]	eval-logloss:0.68382
# [74]	eval-logloss:0.68383
# [75]	eval-logloss:0.68372
# [76]	eval-logloss:0.68360
# [77]	eval-logloss:0.68350
# [78]	eval-logloss:0.68344
# [79]	eval-logloss:0.68334
# [80]	eval-logloss:0.68329
# [81]	eval-logloss:0.68324
# [82]	eval-logloss:0.68326
# [83]	eval-logloss:0.68324
# [84]	eval-logloss:0.68311
# [85]	eval-logloss:0.68307
# [86]	eval-logloss:0.68294
# [87]	eval-logloss:0.68288
# [88]	eval-logloss:0.68284
# [89]	eval-logloss:0.68282
# [90]	eval-logloss:0.68279
# [91]	eval-logloss:0.68277
# [92]	eval-logloss:0.68271
# [93]	eval-logloss:0.68267
# [94]	eval-logloss:0.68260
# [95]	eval-logloss:0.68254
# [96]	eval-logloss:0.68253
# [97]	eval-logloss:0.68250
# [98]	eval-logloss:0.68252
# [99]	eval-logloss:0.68248
# [I 2023-11-09 16:28:54,440] Trial 10 finished with value: 0.6824792847077598 and parameters: {'max_depth': 4, 'eta': 0.012017211284131267, 'subsample': 0.6004457263087025, 'colsample_bytree': 0.5441559055257095}. Best is trial 10 with value: 0.6824792847077598.
# [0]	eval-logloss:0.69299
# [1]	eval-logloss:0.69275
# [2]	eval-logloss:0.69263
# [3]	eval-logloss:0.69247
# [4]	eval-logloss:0.69223
# [5]	eval-logloss:0.69204
# [6]	eval-logloss:0.69183
# [7]	eval-logloss:0.69171
# [8]	eval-logloss:0.69150
# [9]	eval-logloss:0.69134
# [10]	eval-logloss:0.69110
# [11]	eval-logloss:0.69092
# [12]	eval-logloss:0.69069
# [13]	eval-logloss:0.69057
# [14]	eval-logloss:0.69050
# [15]	eval-logloss:0.69036
# [16]	eval-logloss:0.69023
# [17]	eval-logloss:0.69006
# [18]	eval-logloss:0.68993
# [19]	eval-logloss:0.68983
# [20]	eval-logloss:0.68962
# [21]	eval-logloss:0.68948
# [22]	eval-logloss:0.68935
# [23]	eval-logloss:0.68928
# [24]	eval-logloss:0.68919
# [25]	eval-logloss:0.68906
# [26]	eval-logloss:0.68887
# [27]	eval-logloss:0.68869
# [28]	eval-logloss:0.68870
# [29]	eval-logloss:0.68863
# [30]	eval-logloss:0.68847
# [31]	eval-logloss:0.68843
# [32]	eval-logloss:0.68815
# [33]	eval-logloss:0.68806
# [34]	eval-logloss:0.68789
# [35]	eval-logloss:0.68774
# [36]	eval-logloss:0.68763
# [37]	eval-logloss:0.68751
# [38]	eval-logloss:0.68740
# [39]	eval-logloss:0.68715
# [40]	eval-logloss:0.68707
# [41]	eval-logloss:0.68710
# [42]	eval-logloss:0.68702
# [43]	eval-logloss:0.68691
# [44]	eval-logloss:0.68680
# [45]	eval-logloss:0.68675
# [46]	eval-logloss:0.68660
# [47]	eval-logloss:0.68656
# [48]	eval-logloss:0.68643
# [49]	eval-logloss:0.68630
# [50]	eval-logloss:0.68621
# [51]	eval-logloss:0.68608
# [52]	eval-logloss:0.68592
# [53]	eval-logloss:0.68577
# [54]	eval-logloss:0.68570
# [55]	eval-logloss:0.68553
# [56]	eval-logloss:0.68539
# [57]	eval-logloss:0.68526
# [58]	eval-logloss:0.68519
# [59]	eval-logloss:0.68508
# [60]	eval-logloss:0.68494
# [61]	eval-logloss:0.68486
# [62]	eval-logloss:0.68487
# [63]	eval-logloss:0.68482
# [64]	eval-logloss:0.68480
# [65]	eval-logloss:0.68467
# [66]	eval-logloss:0.68452
# [67]	eval-logloss:0.68445
# [68]	eval-logloss:0.68441
# [69]	eval-logloss:0.68433
# [70]	eval-logloss:0.68430
# [71]	eval-logloss:0.68423
# [72]	eval-logloss:0.68418
# [73]	eval-logloss:0.68405
# [74]	eval-logloss:0.68411
# [75]	eval-logloss:0.68401
# [76]	eval-logloss:0.68388
# [77]	eval-logloss:0.68380
# [78]	eval-logloss:0.68377
# [79]	eval-logloss:0.68366
# [80]	eval-logloss:0.68364
# [81]	eval-logloss:0.68362
# [82]	eval-logloss:0.68369
# [83]	eval-logloss:0.68366
# [84]	eval-logloss:0.68353
# [85]	eval-logloss:0.68350
# [86]	eval-logloss:0.68338
# [87]	eval-logloss:0.68332
# [88]	eval-logloss:0.68328
# [89]	eval-logloss:0.68329
# [90]	eval-logloss:0.68327
# [91]	eval-logloss:0.68330
# [92]	eval-logloss:0.68324
# [93]	eval-logloss:0.68321
# [94]	eval-logloss:0.68314
# [95]	eval-logloss:0.68309
# [96]	eval-logloss:0.68309
# [97]	eval-logloss:0.68309
# [98]	eval-logloss:0.68313
# [99]	eval-logloss:0.68310
# [I 2023-11-09 16:28:55,867] Trial 11 finished with value: 0.683097781476036 and parameters: {'max_depth': 3, 'eta': 0.01688918634433647, 'subsample': 0.6114050521463743, 'colsample_bytree': 0.514844978892472}. Best is trial 11 with value: 0.683097781476036.
# [0]	eval-logloss:0.69296
# [1]	eval-logloss:0.69271
# [2]	eval-logloss:0.69256
# [3]	eval-logloss:0.69235
# [4]	eval-logloss:0.69207
# [5]	eval-logloss:0.69184
# [6]	eval-logloss:0.69160
# [7]	eval-logloss:0.69145
# [8]	eval-logloss:0.69123
# [9]	eval-logloss:0.69104
# [10]	eval-logloss:0.69075
# [11]	eval-logloss:0.69052
# [12]	eval-logloss:0.69025
# [13]	eval-logloss:0.69009
# [14]	eval-logloss:0.68999
# [15]	eval-logloss:0.68982
# [16]	eval-logloss:0.68965
# [17]	eval-logloss:0.68945
# [18]	eval-logloss:0.68926
# [19]	eval-logloss:0.68913
# [20]	eval-logloss:0.68891
# [21]	eval-logloss:0.68874
# [22]	eval-logloss:0.68859
# [23]	eval-logloss:0.68847
# [24]	eval-logloss:0.68835
# [25]	eval-logloss:0.68821
# [26]	eval-logloss:0.68798
# [27]	eval-logloss:0.68779
# [28]	eval-logloss:0.68776
# [29]	eval-logloss:0.68766
# [30]	eval-logloss:0.68750
# [31]	eval-logloss:0.68741
# [32]	eval-logloss:0.68709
# [33]	eval-logloss:0.68696
# [34]	eval-logloss:0.68676
# [35]	eval-logloss:0.68661
# [36]	eval-logloss:0.68649
# [37]	eval-logloss:0.68633
# [38]	eval-logloss:0.68618
# [39]	eval-logloss:0.68592
# [40]	eval-logloss:0.68582
# [41]	eval-logloss:0.68581
# [42]	eval-logloss:0.68571
# [43]	eval-logloss:0.68559
# [44]	eval-logloss:0.68547
# [45]	eval-logloss:0.68540
# [46]	eval-logloss:0.68523
# [47]	eval-logloss:0.68515
# [48]	eval-logloss:0.68499
# [49]	eval-logloss:0.68487
# [50]	eval-logloss:0.68475
# [51]	eval-logloss:0.68462
# [52]	eval-logloss:0.68443
# [53]	eval-logloss:0.68426
# [54]	eval-logloss:0.68417
# [55]	eval-logloss:0.68399
# [56]	eval-logloss:0.68382
# [57]	eval-logloss:0.68366
# [58]	eval-logloss:0.68360
# [59]	eval-logloss:0.68348
# [60]	eval-logloss:0.68333
# [61]	eval-logloss:0.68323
# [62]	eval-logloss:0.68321
# [63]	eval-logloss:0.68313
# [64]	eval-logloss:0.68309
# [65]	eval-logloss:0.68297
# [66]	eval-logloss:0.68283
# [67]	eval-logloss:0.68276
# [68]	eval-logloss:0.68270
# [69]	eval-logloss:0.68260
# [70]	eval-logloss:0.68253
# [71]	eval-logloss:0.68244
# [72]	eval-logloss:0.68237
# [73]	eval-logloss:0.68224
# [74]	eval-logloss:0.68229
# [75]	eval-logloss:0.68217
# [76]	eval-logloss:0.68203
# [77]	eval-logloss:0.68192
# [78]	eval-logloss:0.68186
# [79]	eval-logloss:0.68177
# [80]	eval-logloss:0.68172
# [81]	eval-logloss:0.68167
# [82]	eval-logloss:0.68172
# [83]	eval-logloss:0.68169
# [84]	eval-logloss:0.68154
# [85]	eval-logloss:0.68151
# [86]	eval-logloss:0.68135
# [87]	eval-logloss:0.68129
# [88]	eval-logloss:0.68121
# [89]	eval-logloss:0.68118
# [90]	eval-logloss:0.68115
# [91]	eval-logloss:0.68115
# [92]	eval-logloss:0.68108
# [93]	eval-logloss:0.68103
# [94]	eval-logloss:0.68095
# [95]	eval-logloss:0.68089
# [96]	eval-logloss:0.68088
# [97]	eval-logloss:0.68086
# [98]	eval-logloss:0.68090
# [99]	eval-logloss:0.68086
# [I 2023-11-09 16:28:57,299] Trial 12 finished with value: 0.6808617603830558 and parameters: {'max_depth': 4, 'eta': 0.01567208470392989, 'subsample': 0.6010868251008338, 'colsample_bytree': 0.5009795754365493}. Best is trial 11 with value: 0.683097781476036.
# [0]	eval-logloss:0.69153
# [1]	eval-logloss:0.68974
# [2]	eval-logloss:0.68871
# [3]	eval-logloss:0.68719
# [4]	eval-logloss:0.68576
# [5]	eval-logloss:0.68439
# [6]	eval-logloss:0.68299
# [7]	eval-logloss:0.68227
# [8]	eval-logloss:0.68113
# [9]	eval-logloss:0.68014
# [10]	eval-logloss:0.67879
# [11]	eval-logloss:0.67788
# [12]	eval-logloss:0.67699
# [13]	eval-logloss:0.67678
# [14]	eval-logloss:0.67638
# [15]	eval-logloss:0.67600
# [16]	eval-logloss:0.67515
# [17]	eval-logloss:0.67454
# [18]	eval-logloss:0.67410
# [19]	eval-logloss:0.67389
# [20]	eval-logloss:0.67321
# [21]	eval-logloss:0.67278
# [22]	eval-logloss:0.67246
# [23]	eval-logloss:0.67228
# [24]	eval-logloss:0.67210
# [25]	eval-logloss:0.67164
# [26]	eval-logloss:0.67102
# [27]	eval-logloss:0.67043
# [28]	eval-logloss:0.67044
# [29]	eval-logloss:0.67055
# [30]	eval-logloss:0.67009
# [31]	eval-logloss:0.66978
# [32]	eval-logloss:0.66868
# [33]	eval-logloss:0.66850
# [34]	eval-logloss:0.66813
# [35]	eval-logloss:0.66768
# [36]	eval-logloss:0.66774
# [37]	eval-logloss:0.66722
# [38]	eval-logloss:0.66704
# [39]	eval-logloss:0.66602
# [40]	eval-logloss:0.66578
# [41]	eval-logloss:0.66612
# [42]	eval-logloss:0.66582
# [43]	eval-logloss:0.66558
# [44]	eval-logloss:0.66553
# [45]	eval-logloss:0.66562
# [46]	eval-logloss:0.66498
# [47]	eval-logloss:0.66460
# [48]	eval-logloss:0.66423
# [49]	eval-logloss:0.66394
# [50]	eval-logloss:0.66352
# [51]	eval-logloss:0.66335
# [52]	eval-logloss:0.66285
# [53]	eval-logloss:0.66228
# [54]	eval-logloss:0.66202
# [55]	eval-logloss:0.66138
# [56]	eval-logloss:0.66083
# [57]	eval-logloss:0.66024
# [58]	eval-logloss:0.66004
# [59]	eval-logloss:0.65969
# [60]	eval-logloss:0.65908
# [61]	eval-logloss:0.65881
# [62]	eval-logloss:0.65898
# [63]	eval-logloss:0.65885
# [64]	eval-logloss:0.65897
# [65]	eval-logloss:0.65836
# [66]	eval-logloss:0.65782
# [67]	eval-logloss:0.65792
# [68]	eval-logloss:0.65788
# [69]	eval-logloss:0.65774
# [70]	eval-logloss:0.65764
# [71]	eval-logloss:0.65751
# [72]	eval-logloss:0.65739
# [73]	eval-logloss:0.65728
# [74]	eval-logloss:0.65766
# [75]	eval-logloss:0.65731
# [76]	eval-logloss:0.65704
# [77]	eval-logloss:0.65691
# [78]	eval-logloss:0.65672
# [79]	eval-logloss:0.65649
# [80]	eval-logloss:0.65649
# [81]	eval-logloss:0.65635
# [82]	eval-logloss:0.65670
# [83]	eval-logloss:0.65650
# [84]	eval-logloss:0.65588
# [85]	eval-logloss:0.65587
# [86]	eval-logloss:0.65535
# [87]	eval-logloss:0.65527
# [88]	eval-logloss:0.65507
# [89]	eval-logloss:0.65521
# [90]	eval-logloss:0.65510
# [91]	eval-logloss:0.65507
# [92]	eval-logloss:0.65482
# [93]	eval-logloss:0.65474
# [94]	eval-logloss:0.65435
# [95]	eval-logloss:0.65430
# [96]	eval-logloss:0.65424
# [97]	eval-logloss:0.65426
# [98]	eval-logloss:0.65449
# [99]	eval-logloss:0.65420
# [I 2023-11-09 16:28:58,970] Trial 13 finished with value: 0.6542017142711163 and parameters: {'max_depth': 6, 'eta': 0.08079773178856525, 'subsample': 0.6001518308625453, 'colsample_bytree': 0.5151074158797463}. Best is trial 11 with value: 0.683097781476036.
# [0]	eval-logloss:0.69289
# [1]	eval-logloss:0.69252
# [2]	eval-logloss:0.69235
# [3]	eval-logloss:0.69206
# [4]	eval-logloss:0.69179
# [5]	eval-logloss:0.69151
# [6]	eval-logloss:0.69120
# [7]	eval-logloss:0.69100
# [8]	eval-logloss:0.69070
# [9]	eval-logloss:0.69046
# [10]	eval-logloss:0.69016
# [11]	eval-logloss:0.68996
# [12]	eval-logloss:0.68967
# [13]	eval-logloss:0.68949
# [14]	eval-logloss:0.68936
# [15]	eval-logloss:0.68914
# [16]	eval-logloss:0.68892
# [17]	eval-logloss:0.68866
# [18]	eval-logloss:0.68843
# [19]	eval-logloss:0.68828
# [20]	eval-logloss:0.68801
# [21]	eval-logloss:0.68781
# [22]	eval-logloss:0.68762
# [23]	eval-logloss:0.68749
# [24]	eval-logloss:0.68733
# [25]	eval-logloss:0.68720
# [26]	eval-logloss:0.68695
# [27]	eval-logloss:0.68672
# [28]	eval-logloss:0.68670
# [29]	eval-logloss:0.68659
# [30]	eval-logloss:0.68643
# [31]	eval-logloss:0.68633
# [32]	eval-logloss:0.68598
# [33]	eval-logloss:0.68585
# [34]	eval-logloss:0.68565
# [35]	eval-logloss:0.68547
# [36]	eval-logloss:0.68531
# [37]	eval-logloss:0.68515
# [38]	eval-logloss:0.68502
# [39]	eval-logloss:0.68474
# [40]	eval-logloss:0.68464
# [41]	eval-logloss:0.68460
# [42]	eval-logloss:0.68451
# [43]	eval-logloss:0.68434
# [44]	eval-logloss:0.68421
# [45]	eval-logloss:0.68415
# [46]	eval-logloss:0.68398
# [47]	eval-logloss:0.68388
# [48]	eval-logloss:0.68375
# [49]	eval-logloss:0.68361
# [50]	eval-logloss:0.68351
# [51]	eval-logloss:0.68338
# [52]	eval-logloss:0.68320
# [53]	eval-logloss:0.68299
# [54]	eval-logloss:0.68290
# [55]	eval-logloss:0.68274
# [56]	eval-logloss:0.68255
# [57]	eval-logloss:0.68242
# [58]	eval-logloss:0.68236
# [59]	eval-logloss:0.68223
# [60]	eval-logloss:0.68206
# [61]	eval-logloss:0.68197
# [62]	eval-logloss:0.68198
# [63]	eval-logloss:0.68194
# [64]	eval-logloss:0.68190
# [65]	eval-logloss:0.68174
# [66]	eval-logloss:0.68160
# [67]	eval-logloss:0.68148
# [68]	eval-logloss:0.68146
# [69]	eval-logloss:0.68137
# [70]	eval-logloss:0.68127
# [71]	eval-logloss:0.68124
# [72]	eval-logloss:0.68119
# [73]	eval-logloss:0.68112
# [74]	eval-logloss:0.68117
# [75]	eval-logloss:0.68104
# [76]	eval-logloss:0.68092
# [77]	eval-logloss:0.68081
# [78]	eval-logloss:0.68073
# [79]	eval-logloss:0.68064
# [80]	eval-logloss:0.68063
# [81]	eval-logloss:0.68058
# [82]	eval-logloss:0.68065
# [83]	eval-logloss:0.68060
# [84]	eval-logloss:0.68052
# [85]	eval-logloss:0.68048
# [86]	eval-logloss:0.68033
# [87]	eval-logloss:0.68025
# [88]	eval-logloss:0.68020
# [89]	eval-logloss:0.68020
# [90]	eval-logloss:0.68012
# [91]	eval-logloss:0.68014
# [92]	eval-logloss:0.68008
# [93]	eval-logloss:0.67999
# [94]	eval-logloss:0.67991
# [95]	eval-logloss:0.67986
# [96]	eval-logloss:0.67983
# [97]	eval-logloss:0.67984
# [98]	eval-logloss:0.67986
# [99]	eval-logloss:0.67982
# [I 2023-11-09 16:29:00,449] Trial 14 finished with value: 0.6798162307622003 and parameters: {'max_depth': 4, 'eta': 0.018872828869097052, 'subsample': 0.6504407575463677, 'colsample_bytree': 0.5676266546155955}. Best is trial 11 with value: 0.683097781476036.
# [0]	eval-logloss:0.69194
# [1]	eval-logloss:0.69024
# [2]	eval-logloss:0.68948
# [3]	eval-logloss:0.68855
# [4]	eval-logloss:0.68759
# [5]	eval-logloss:0.68684
# [6]	eval-logloss:0.68599
# [7]	eval-logloss:0.68547
# [8]	eval-logloss:0.68425
# [9]	eval-logloss:0.68339
# [10]	eval-logloss:0.68254
# [11]	eval-logloss:0.68223
# [12]	eval-logloss:0.68170
# [13]	eval-logloss:0.68148
# [14]	eval-logloss:0.68129
# [15]	eval-logloss:0.68099
# [16]	eval-logloss:0.68033
# [17]	eval-logloss:0.67990
# [18]	eval-logloss:0.67975
# [19]	eval-logloss:0.67992
# [20]	eval-logloss:0.67939
# [21]	eval-logloss:0.67909
# [22]	eval-logloss:0.67896
# [23]	eval-logloss:0.67904
# [24]	eval-logloss:0.67904
# [25]	eval-logloss:0.67898
# [26]	eval-logloss:0.67849
# [27]	eval-logloss:0.67791
# [28]	eval-logloss:0.67821
# [29]	eval-logloss:0.67823
# [30]	eval-logloss:0.67770
# [31]	eval-logloss:0.67784
# [32]	eval-logloss:0.67677
# [33]	eval-logloss:0.67678
# [34]	eval-logloss:0.67651
# [35]	eval-logloss:0.67615
# [36]	eval-logloss:0.67593
# [37]	eval-logloss:0.67547
# [38]	eval-logloss:0.67554
# [39]	eval-logloss:0.67466
# [40]	eval-logloss:0.67459
# [41]	eval-logloss:0.67506
# [42]	eval-logloss:0.67507
# [43]	eval-logloss:0.67492
# [44]	eval-logloss:0.67496
# [45]	eval-logloss:0.67504
# [46]	eval-logloss:0.67439
# [47]	eval-logloss:0.67453
# [48]	eval-logloss:0.67438
# [49]	eval-logloss:0.67427
# [50]	eval-logloss:0.67415
# [51]	eval-logloss:0.67392
# [52]	eval-logloss:0.67339
# [53]	eval-logloss:0.67280
# [54]	eval-logloss:0.67285
# [55]	eval-logloss:0.67243
# [56]	eval-logloss:0.67209
# [57]	eval-logloss:0.67183
# [58]	eval-logloss:0.67180
# [59]	eval-logloss:0.67154
# [60]	eval-logloss:0.67099
# [61]	eval-logloss:0.67110
# [62]	eval-logloss:0.67160
# [63]	eval-logloss:0.67168
# [64]	eval-logloss:0.67201
# [65]	eval-logloss:0.67160
# [66]	eval-logloss:0.67106
# [67]	eval-logloss:0.67110
# [68]	eval-logloss:0.67133
# [69]	eval-logloss:0.67132
# [70]	eval-logloss:0.67116
# [71]	eval-logloss:0.67132
# [72]	eval-logloss:0.67147
# [73]	eval-logloss:0.67152
# [74]	eval-logloss:0.67203
# [75]	eval-logloss:0.67170
# [76]	eval-logloss:0.67131
# [77]	eval-logloss:0.67109
# [78]	eval-logloss:0.67107
# [79]	eval-logloss:0.67091
# [80]	eval-logloss:0.67105
# [81]	eval-logloss:0.67121
# [82]	eval-logloss:0.67170
# [83]	eval-logloss:0.67153
# [84]	eval-logloss:0.67102
# [85]	eval-logloss:0.67098
# [86]	eval-logloss:0.67036
# [87]	eval-logloss:0.67023
# [88]	eval-logloss:0.67024
# [89]	eval-logloss:0.67062
# [90]	eval-logloss:0.67054
# [91]	eval-logloss:0.67067
# [92]	eval-logloss:0.67041
# [93]	eval-logloss:0.67026
# [94]	eval-logloss:0.66988
# [95]	eval-logloss:0.66996
# [96]	eval-logloss:0.66978
# [97]	eval-logloss:0.66999
# [98]	eval-logloss:0.67015
# [99]	eval-logloss:0.67009
# [I 2023-11-09 16:29:01,883] Trial 15 finished with value: 0.6700909026986978 and parameters: {'max_depth': 4, 'eta': 0.0996101258329079, 'subsample': 0.6412160603506969, 'colsample_bytree': 0.574876379187204}. Best is trial 11 with value: 0.683097781476036.
# [0]	eval-logloss:0.69205
# [1]	eval-logloss:0.69082
# [2]	eval-logloss:0.68999
# [3]	eval-logloss:0.68883
# [4]	eval-logloss:0.68786
# [5]	eval-logloss:0.68680
# [6]	eval-logloss:0.68574
# [7]	eval-logloss:0.68520
# [8]	eval-logloss:0.68423
# [9]	eval-logloss:0.68356
# [10]	eval-logloss:0.68262
# [11]	eval-logloss:0.68198
# [12]	eval-logloss:0.68121
# [13]	eval-logloss:0.68065
# [14]	eval-logloss:0.68027
# [15]	eval-logloss:0.67981
# [16]	eval-logloss:0.67928
# [17]	eval-logloss:0.67869
# [18]	eval-logloss:0.67820
# [19]	eval-logloss:0.67785
# [20]	eval-logloss:0.67726
# [21]	eval-logloss:0.67678
# [22]	eval-logloss:0.67646
# [23]	eval-logloss:0.67628
# [24]	eval-logloss:0.67615
# [25]	eval-logloss:0.67588
# [26]	eval-logloss:0.67526
# [27]	eval-logloss:0.67474
# [28]	eval-logloss:0.67471
# [29]	eval-logloss:0.67436
# [30]	eval-logloss:0.67395
# [31]	eval-logloss:0.67380
# [32]	eval-logloss:0.67309
# [33]	eval-logloss:0.67284
# [34]	eval-logloss:0.67238
# [35]	eval-logloss:0.67192
# [36]	eval-logloss:0.67154
# [37]	eval-logloss:0.67127
# [38]	eval-logloss:0.67102
# [39]	eval-logloss:0.67045
# [40]	eval-logloss:0.67020
# [41]	eval-logloss:0.67029
# [42]	eval-logloss:0.67014
# [43]	eval-logloss:0.66976
# [44]	eval-logloss:0.66957
# [45]	eval-logloss:0.66945
# [46]	eval-logloss:0.66906
# [47]	eval-logloss:0.66889
# [48]	eval-logloss:0.66893
# [49]	eval-logloss:0.66867
# [50]	eval-logloss:0.66846
# [51]	eval-logloss:0.66831
# [52]	eval-logloss:0.66779
# [53]	eval-logloss:0.66755
# [54]	eval-logloss:0.66730
# [55]	eval-logloss:0.66708
# [56]	eval-logloss:0.66670
# [57]	eval-logloss:0.66637
# [58]	eval-logloss:0.66632
# [59]	eval-logloss:0.66603
# [60]	eval-logloss:0.66557
# [61]	eval-logloss:0.66535
# [62]	eval-logloss:0.66549
# [63]	eval-logloss:0.66540
# [64]	eval-logloss:0.66546
# [65]	eval-logloss:0.66480
# [66]	eval-logloss:0.66450
# [67]	eval-logloss:0.66428
# [68]	eval-logloss:0.66429
# [69]	eval-logloss:0.66424
# [70]	eval-logloss:0.66425
# [71]	eval-logloss:0.66427
# [72]	eval-logloss:0.66414
# [73]	eval-logloss:0.66422
# [74]	eval-logloss:0.66442
# [75]	eval-logloss:0.66411
# [76]	eval-logloss:0.66371
# [77]	eval-logloss:0.66349
# [78]	eval-logloss:0.66326
# [79]	eval-logloss:0.66326
# [80]	eval-logloss:0.66340
# [81]	eval-logloss:0.66331
# [82]	eval-logloss:0.66343
# [83]	eval-logloss:0.66339
# [84]	eval-logloss:0.66321
# [85]	eval-logloss:0.66315
# [86]	eval-logloss:0.66292
# [87]	eval-logloss:0.66288
# ...
# [43]	eval-logloss:0.68728
# [44]	eval-logloss:0.68718
# [45]	eval-logloss:0.68712
# [46]	eval-logloss:0.68701
# [47]	eval-logloss:0.68691
# [48]	eval-logloss:0.68685
# [49]	eval-logloss:0.68673
# [50]	eval-logloss:0.68664
# [51]	eval-logloss:0.68655
# [52]	eval-logloss:0.68641
# [53]	eval-logloss:0.68630
# [54]	eval-logloss:0.68622
# [55]	eval-logloss:0.68612
# [56]	eval-logloss:0.68599
# [57]	eval-logloss:0.68587
# [58]	eval-logloss:0.68583
# [59]	eval-logloss:0.68573
# [60]	eval-logloss:0.68561
# [61]	eval-logloss:0.68553
# [62]	eval-logloss:0.68552
# [63]	eval-logloss:0.68549
# [64]	eval-logloss:0.68546
# [65]	eval-logloss:0.68531
# [66]	eval-logloss:0.68522
# [67]	eval-logloss:0.68515
# [68]	eval-logloss:0.68510
# [69]	eval-logloss:0.68507
# [70]	eval-logloss:0.68502
# [71]	eval-logloss:0.68499
# [72]	eval-logloss:0.68494
# [73]	eval-logloss:0.68488
# [74]	eval-logloss:0.68488
# [75]	eval-logloss:0.68477
# [76]	eval-logloss:0.68468
# [77]	eval-logloss:0.68461
# [78]	eval-logloss:0.68453
# [79]	eval-logloss:0.68447
# [80]	eval-logloss:0.68446
# [81]	eval-logloss:0.68443
# [82]	eval-logloss:0.68444
# [83]	eval-logloss:0.68443
# [84]	eval-logloss:0.68435
# [85]	eval-logloss:0.68430
# [86]	eval-logloss:0.68422
# [87]	eval-logloss:0.68415
# [88]	eval-logloss:0.68411
# [89]	eval-logloss:0.68412
# [90]	eval-logloss:0.68405
# [91]	eval-logloss:0.68406
# [92]	eval-logloss:0.68400
# [93]	eval-logloss:0.68393
# [94]	eval-logloss:0.68384
# [95]	eval-logloss:0.68378
# [96]	eval-logloss:0.68377
# [97]	eval-logloss:0.68377
# [98]	eval-logloss:0.68378
# [99]	eval-logloss:0.68376
# [I 2023-11-09 16:29:40,575] Trial 42 finished with value: 0.6837560569896506 and parameters: {'max_depth': 3, 'eta': 0.013870422577051067, 'subsample': 0.6978437135534333, 'colsample_bytree': 0.6214256019344697}. Best is trial 34 with value: 0.685088196510214.
# [0]	eval-logloss:0.69302
# [1]	eval-logloss:0.69288
# [2]	eval-logloss:0.69281
# [3]	eval-logloss:0.69268
# [4]	eval-logloss:0.69256
# [5]	eval-logloss:0.69244
# [6]	eval-logloss:0.69231
# [7]	eval-logloss:0.69223
# [8]	eval-logloss:0.69203
# [9]	eval-logloss:0.69192
# [10]	eval-logloss:0.69178
# [11]	eval-logloss:0.69166
# [12]	eval-logloss:0.69154
# [13]	eval-logloss:0.69143
# [14]	eval-logloss:0.69131
# [15]	eval-logloss:0.69121
# [16]	eval-logloss:0.69114
# [17]	eval-logloss:0.69101
# [18]	eval-logloss:0.69091
# [19]	eval-logloss:0.69081
# [20]	eval-logloss:0.69067
# [21]	eval-logloss:0.69058
# [22]	eval-logloss:0.69048
# [23]	eval-logloss:0.69038
# [24]	eval-logloss:0.69031
# [25]	eval-logloss:0.69025
# [26]	eval-logloss:0.69012
# [27]	eval-logloss:0.69000
# [28]	eval-logloss:0.68996
# [29]	eval-logloss:0.68986
# [30]	eval-logloss:0.68974
# [31]	eval-logloss:0.68970
# [32]	eval-logloss:0.68956
# [33]	eval-logloss:0.68947
# [34]	eval-logloss:0.68937
# [35]	eval-logloss:0.68926
# [36]	eval-logloss:0.68919
# [37]	eval-logloss:0.68910
# [38]	eval-logloss:0.68901
# [39]	eval-logloss:0.68885
# [40]	eval-logloss:0.68877
# [41]	eval-logloss:0.68870
# [42]	eval-logloss:0.68863
# [43]	eval-logloss:0.68853
# [44]	eval-logloss:0.68844
# [45]	eval-logloss:0.68838
# [46]	eval-logloss:0.68829
# [47]	eval-logloss:0.68820
# [48]	eval-logloss:0.68814
# [49]	eval-logloss:0.68804
# [50]	eval-logloss:0.68796
# [51]	eval-logloss:0.68787
# [52]	eval-logloss:0.68774
# [53]	eval-logloss:0.68765
# [54]	eval-logloss:0.68758
# [55]	eval-logloss:0.68749
# [56]	eval-logloss:0.68739
# [57]	eval-logloss:0.68728
# [58]	eval-logloss:0.68725
# [59]	eval-logloss:0.68719
# [60]	eval-logloss:0.68709
# [61]	eval-logloss:0.68702
# [62]	eval-logloss:0.68699
# [63]	eval-logloss:0.68695
# [64]	eval-logloss:0.68690
# [65]	eval-logloss:0.68680
# [66]	eval-logloss:0.68673
# [67]	eval-logloss:0.68665
# [68]	eval-logloss:0.68660
# [69]	eval-logloss:0.68656
# [70]	eval-logloss:0.68651
# [71]	eval-logloss:0.68647
# [72]	eval-logloss:0.68642
# [73]	eval-logloss:0.68635
# [74]	eval-logloss:0.68634
# [75]	eval-logloss:0.68626
# [76]	eval-logloss:0.68617
# [77]	eval-logloss:0.68610
# [78]	eval-logloss:0.68602
# [79]	eval-logloss:0.68597
# [80]	eval-logloss:0.68595
# [81]	eval-logloss:0.68591
# [82]	eval-logloss:0.68590
# [83]	eval-logloss:0.68588
# [84]	eval-logloss:0.68582
# [85]	eval-logloss:0.68577
# [86]	eval-logloss:0.68568
# [87]	eval-logloss:0.68562
# [88]	eval-logloss:0.68557
# [89]	eval-logloss:0.68556
# [90]	eval-logloss:0.68549
# [91]	eval-logloss:0.68548
# [92]	eval-logloss:0.68543
# [93]	eval-logloss:0.68539
# [94]	eval-logloss:0.68530
# [95]	eval-logloss:0.68524
# [96]	eval-logloss:0.68523
# [97]	eval-logloss:0.68522
# [98]	eval-logloss:0.68521
# [99]	eval-logloss:0.68518
# [I 2023-11-09 16:29:42,007] Trial 43 finished with value: 0.6851802125792505 and parameters: {'max_depth': 3, 'eta': 0.010024132211789522, 'subsample': 0.7117944632061203, 'colsample_bytree': 0.6265678003528262}. Best is trial 43 with value: 0.6851802125792505.
# [0]	eval-logloss:0.69258
# [1]	eval-logloss:0.69196
# [2]	eval-logloss:0.69168
# [3]	eval-logloss:0.69117
# [4]	eval-logloss:0.69067
# [5]	eval-logloss:0.69029
# [6]	eval-logloss:0.68984
# [7]	eval-logloss:0.68955
# [8]	eval-logloss:0.68893
# [9]	eval-logloss:0.68849
# [10]	eval-logloss:0.68813
# [11]	eval-logloss:0.68778
# [12]	eval-logloss:0.68749
# [13]	eval-logloss:0.68726
# [14]	eval-logloss:0.68699
# [15]	eval-logloss:0.68674
# [16]	eval-logloss:0.68649
# [17]	eval-logloss:0.68612
# [18]	eval-logloss:0.68602
# [19]	eval-logloss:0.68584
# [20]	eval-logloss:0.68550
# [21]	eval-logloss:0.68532
# [22]	eval-logloss:0.68515
# [23]	eval-logloss:0.68505
# [24]	eval-logloss:0.68510
# [25]	eval-logloss:0.68503
# [26]	eval-logloss:0.68474
# [27]	eval-logloss:0.68450
# [28]	eval-logloss:0.68445
# [29]	eval-logloss:0.68429
# [30]	eval-logloss:0.68399
# [31]	eval-logloss:0.68398
# [32]	eval-logloss:0.68371
# [33]	eval-logloss:0.68353
# [34]	eval-logloss:0.68336
# [35]	eval-logloss:0.68321
# [36]	eval-logloss:0.68313
# [37]	eval-logloss:0.68297
# [38]	eval-logloss:0.68290
# [39]	eval-logloss:0.68251
# [40]	eval-logloss:0.68249
# [41]	eval-logloss:0.68260
# [42]	eval-logloss:0.68252
# [43]	eval-logloss:0.68242
# [44]	eval-logloss:0.68235
# [45]	eval-logloss:0.68226
# [46]	eval-logloss:0.68208
# [47]	eval-logloss:0.68190
# [48]	eval-logloss:0.68193
# [49]	eval-logloss:0.68182
# [50]	eval-logloss:0.68173
# [51]	eval-logloss:0.68161
# [52]	eval-logloss:0.68129
# [53]	eval-logloss:0.68098
# [54]	eval-logloss:0.68092
# [55]	eval-logloss:0.68069
# [56]	eval-logloss:0.68054
# [57]	eval-logloss:0.68029
# [58]	eval-logloss:0.68031
# [59]	eval-logloss:0.68013
# [60]	eval-logloss:0.67995
# [61]	eval-logloss:0.68003
# [62]	eval-logloss:0.68003
# [63]	eval-logloss:0.68008
# [64]	eval-logloss:0.68008
# [65]	eval-logloss:0.67983
# [66]	eval-logloss:0.67964
# [67]	eval-logloss:0.67954
# [68]	eval-logloss:0.67955
# [69]	eval-logloss:0.67962
# [70]	eval-logloss:0.67966
# [71]	eval-logloss:0.67958
# [72]	eval-logloss:0.67960
# [73]	eval-logloss:0.67957
# [74]	eval-logloss:0.67962
# [75]	eval-logloss:0.67952
# [76]	eval-logloss:0.67926
# [77]	eval-logloss:0.67917
# [78]	eval-logloss:0.67908
# [79]	eval-logloss:0.67914
# [80]	eval-logloss:0.67914
# [81]	eval-logloss:0.67917
# [82]	eval-logloss:0.67930
# [83]	eval-logloss:0.67929
# [84]	eval-logloss:0.67922
# [85]	eval-logloss:0.67919
# [86]	eval-logloss:0.67895
# [87]	eval-logloss:0.67881
# [88]	eval-logloss:0.67871
# [89]	eval-logloss:0.67885
# [90]	eval-logloss:0.67880
# [91]	eval-logloss:0.67885
# [92]	eval-logloss:0.67878
# [93]	eval-logloss:0.67870
# [94]	eval-logloss:0.67849
# [95]	eval-logloss:0.67841
# [96]	eval-logloss:0.67848
# [97]	eval-logloss:0.67860
# [98]	eval-logloss:0.67880
# [99]	eval-logloss:0.67875
# [I 2023-11-09 16:29:43,325] Trial 44 finished with value: 0.6787459221048512 and parameters: {'max_depth': 3, 'eta': 0.046175356270333034, 'subsample': 0.7382231307720583, 'colsample_bytree': 0.6664394290184525}. Best is trial 43 with value: 0.6851802125792505.
# [0]	eval-logloss:0.69231
# [1]	eval-logloss:0.69146
# [2]	eval-logloss:0.69107
# [3]	eval-logloss:0.69041
# [4]	eval-logloss:0.68982
# [5]	eval-logloss:0.68937
# [6]	eval-logloss:0.68880
# [7]	eval-logloss:0.68860
# [8]	eval-logloss:0.68787
# [9]	eval-logloss:0.68738
# [10]	eval-logloss:0.68676
# [11]	eval-logloss:0.68637
# [12]	eval-logloss:0.68596
# [13]	eval-logloss:0.68574
# [14]	eval-logloss:0.68563
# [15]	eval-logloss:0.68548
# [16]	eval-logloss:0.68520
# [17]	eval-logloss:0.68483
# [18]	eval-logloss:0.68469
# [19]	eval-logloss:0.68454
# [20]	eval-logloss:0.68415
# [21]	eval-logloss:0.68394
# [22]	eval-logloss:0.68380
# [23]	eval-logloss:0.68365
# [24]	eval-logloss:0.68369
# [25]	eval-logloss:0.68365
# [26]	eval-logloss:0.68330
# [27]	eval-logloss:0.68291
# [28]	eval-logloss:0.68300
# [29]	eval-logloss:0.68278
# [30]	eval-logloss:0.68251
# [31]	eval-logloss:0.68258
# [32]	eval-logloss:0.68211
# [33]	eval-logloss:0.68208
# [34]	eval-logloss:0.68193
# [35]	eval-logloss:0.68168
# [36]	eval-logloss:0.68155
# [37]	eval-logloss:0.68144
# [38]	eval-logloss:0.68134
# [39]	eval-logloss:0.68077
# [40]	eval-logloss:0.68072
# [41]	eval-logloss:0.68081
# [42]	eval-logloss:0.68077
# [43]	eval-logloss:0.68067
# [44]	eval-logloss:0.68067
# [45]	eval-logloss:0.68059
# [46]	eval-logloss:0.68038
# [47]	eval-logloss:0.68025
# [48]	eval-logloss:0.68032
# [49]	eval-logloss:0.68014
# [50]	eval-logloss:0.68009
# [51]	eval-logloss:0.68000
# [52]	eval-logloss:0.67966
# [53]	eval-logloss:0.67931
# [54]	eval-logloss:0.67925
# [55]	eval-logloss:0.67905
# [56]	eval-logloss:0.67886
# [57]	eval-logloss:0.67860
# [58]	eval-logloss:0.67870
# [59]	eval-logloss:0.67857
# [60]	eval-logloss:0.67832
# [61]	eval-logloss:0.67835
# [62]	eval-logloss:0.67850
# [63]	eval-logloss:0.67864
# [64]	eval-logloss:0.67878
# [65]	eval-logloss:0.67835
# [66]	eval-logloss:0.67811
# [67]	eval-logloss:0.67806
# [68]	eval-logloss:0.67809
# [69]	eval-logloss:0.67817
# [70]	eval-logloss:0.67819
# [71]	eval-logloss:0.67823
# [72]	eval-logloss:0.67828
# [73]	eval-logloss:0.67836
# [74]	eval-logloss:0.67861
# [75]	eval-logloss:0.67837
# [76]	eval-logloss:0.67806
# [77]	eval-logloss:0.67791
# [78]	eval-logloss:0.67784
# [79]	eval-logloss:0.67792
# [80]	eval-logloss:0.67804
# [81]	eval-logloss:0.67813
# [82]	eval-logloss:0.67829
# [83]	eval-logloss:0.67832
# [84]	eval-logloss:0.67818
# [85]	eval-logloss:0.67822
# [86]	eval-logloss:0.67787
# [87]	eval-logloss:0.67772
# [88]	eval-logloss:0.67770
# [89]	eval-logloss:0.67798
# [90]	eval-logloss:0.67783
# [91]	eval-logloss:0.67794
# [92]	eval-logloss:0.67786
# [93]	eval-logloss:0.67778
# [94]	eval-logloss:0.67746
# [95]	eval-logloss:0.67735
# [96]	eval-logloss:0.67741
# [97]	eval-logloss:0.67755
# [98]	eval-logloss:0.67779
# [99]	eval-logloss:0.67774
# [I 2023-11-09 16:29:44,606] Trial 45 finished with value: 0.6777385235276996 and parameters: {'max_depth': 3, 'eta': 0.0645734411661115, 'subsample': 0.7065582365777161, 'colsample_bytree': 0.5915973910760022}. Best is trial 43 with value: 0.6851802125792505.
# [0]	eval-logloss:0.69277
# [1]	eval-logloss:0.69234
# [2]	eval-logloss:0.69214
# [3]	eval-logloss:0.69178
# [4]	eval-logloss:0.69144
# [5]	eval-logloss:0.69116
# [6]	eval-logloss:0.69081
# [7]	eval-logloss:0.69061
# [8]	eval-logloss:0.69009
# [9]	eval-logloss:0.68981
# [10]	eval-logloss:0.68945
# [11]	eval-logloss:0.68918
# [12]	eval-logloss:0.68892
# [13]	eval-logloss:0.68871
# [14]	eval-logloss:0.68848
# [15]	eval-logloss:0.68829
# [16]	eval-logloss:0.68810
# [17]	eval-logloss:0.68784
# [18]	eval-logloss:0.68767
# [19]	eval-logloss:0.68753
# [20]	eval-logloss:0.68725
# [21]	eval-logloss:0.68710
# [22]	eval-logloss:0.68691
# [23]	eval-logloss:0.68680
# [24]	eval-logloss:0.68674
# [25]	eval-logloss:0.68666
# [26]	eval-logloss:0.68641
# [27]	eval-logloss:0.68617
# [28]	eval-logloss:0.68616
# [29]	eval-logloss:0.68595
# [30]	eval-logloss:0.68574
# [31]	eval-logloss:0.68573
# [32]	eval-logloss:0.68540
# [33]	eval-logloss:0.68528
# [34]	eval-logloss:0.68512
# [35]	eval-logloss:0.68494
# [36]	eval-logloss:0.68480
# [37]	eval-logloss:0.68467
# [38]	eval-logloss:0.68455
# [39]	eval-logloss:0.68422
# [40]	eval-logloss:0.68411
# [41]	eval-logloss:0.68410
# [42]	eval-logloss:0.68402
# [43]	eval-logloss:0.68391
# [44]	eval-logloss:0.68378
# [45]	eval-logloss:0.68376
# [46]	eval-logloss:0.68358
# [47]	eval-logloss:0.68349
# [48]	eval-logloss:0.68344
# [49]	eval-logloss:0.68329
# [50]	eval-logloss:0.68319
# [51]	eval-logloss:0.68309
# [52]	eval-logloss:0.68291
# [53]	eval-logloss:0.68274
# [54]	eval-logloss:0.68263
# [55]	eval-logloss:0.68249
# [56]	eval-logloss:0.68236
# [57]	eval-logloss:0.68220
# [58]	eval-logloss:0.68216
# [59]	eval-logloss:0.68200
# [60]	eval-logloss:0.68183
# [61]	eval-logloss:0.68176
# [62]	eval-logloss:0.68181
# [63]	eval-logloss:0.68183
# [64]	eval-logloss:0.68188
# [65]	eval-logloss:0.68162
# [66]	eval-logloss:0.68148
# [67]	eval-logloss:0.68141
# [68]	eval-logloss:0.68137
# [69]	eval-logloss:0.68136
# [70]	eval-logloss:0.68132
# [71]	eval-logloss:0.68134
# [72]	eval-logloss:0.68134
# [73]	eval-logloss:0.68132
# [74]	eval-logloss:0.68139
# [75]	eval-logloss:0.68125
# [76]	eval-logloss:0.68108
# [77]	eval-logloss:0.68099
# [78]	eval-logloss:0.68090
# [79]	eval-logloss:0.68086
# [80]	eval-logloss:0.68088
# [81]	eval-logloss:0.68089
# [82]	eval-logloss:0.68095
# [83]	eval-logloss:0.68099
# [84]	eval-logloss:0.68088
# [85]	eval-logloss:0.68085
# [86]	eval-logloss:0.68071
# [87]	eval-logloss:0.68065
# [88]	eval-logloss:0.68060
# [89]	eval-logloss:0.68069
# [90]	eval-logloss:0.68062
# [91]	eval-logloss:0.68068
# [92]	eval-logloss:0.68061
# [93]	eval-logloss:0.68053
# [94]	eval-logloss:0.68038
# [95]	eval-logloss:0.68031
# [96]	eval-logloss:0.68033
# [97]	eval-logloss:0.68040
# [98]	eval-logloss:0.68047
# [99]	eval-logloss:0.68045
# [I 2023-11-09 16:29:45,845] Trial 46 finished with value: 0.6804519031604813 and parameters: {'max_depth': 3, 'eta': 0.03007595950283417, 'subsample': 0.6979071062347942, 'colsample_bytree': 0.6367958269761933}. Best is trial 43 with value: 0.6851802125792505.
# [0]	eval-logloss:0.69216
# [1]	eval-logloss:0.69093
# [2]	eval-logloss:0.69051
# [3]	eval-logloss:0.68984
# [4]	eval-logloss:0.68906
# [5]	eval-logloss:0.68849
# [6]	eval-logloss:0.68781
# [7]	eval-logloss:0.68751
# [8]	eval-logloss:0.68681
# [9]	eval-logloss:0.68624
# [10]	eval-logloss:0.68569
# [11]	eval-logloss:0.68529
# [12]	eval-logloss:0.68501
# [13]	eval-logloss:0.68484
# [14]	eval-logloss:0.68472
# [15]	eval-logloss:0.68445
# [16]	eval-logloss:0.68423
# [17]	eval-logloss:0.68375
# [18]	eval-logloss:0.68360
# [19]	eval-logloss:0.68323
# [20]	eval-logloss:0.68290
# [21]	eval-logloss:0.68283
# [22]	eval-logloss:0.68267
# [23]	eval-logloss:0.68246
# [24]	eval-logloss:0.68265
# [25]	eval-logloss:0.68279
# [26]	eval-logloss:0.68245
# [27]	eval-logloss:0.68215
# [28]	eval-logloss:0.68211
# [29]	eval-logloss:0.68194
# [30]	eval-logloss:0.68148
# [31]	eval-logloss:0.68144
# [32]	eval-logloss:0.68123
# [33]	eval-logloss:0.68105
# [34]	eval-logloss:0.68094
# [35]	eval-logloss:0.68074
# [36]	eval-logloss:0.68062
# [37]	eval-logloss:0.68044
# [38]	eval-logloss:0.68046
# [39]	eval-logloss:0.68006
# [40]	eval-logloss:0.68012
# [41]	eval-logloss:0.68029
# [42]	eval-logloss:0.68017
# [43]	eval-logloss:0.67993
# [44]	eval-logloss:0.67990
# [45]	eval-logloss:0.67990
# [46]	eval-logloss:0.67964
# [47]	eval-logloss:0.67956
# [48]	eval-logloss:0.67954
# [49]	eval-logloss:0.67944
# [50]	eval-logloss:0.67927
# [51]	eval-logloss:0.67913
# [52]	eval-logloss:0.67871
# [53]	eval-logloss:0.67828
# [54]	eval-logloss:0.67825
# [55]	eval-logloss:0.67789
# [56]	eval-logloss:0.67774
# [57]	eval-logloss:0.67755
# [58]	eval-logloss:0.67758
# [59]	eval-logloss:0.67739
# [60]	eval-logloss:0.67728
# [61]	eval-logloss:0.67751
# [62]	eval-logloss:0.67752
# [63]	eval-logloss:0.67769
# [64]	eval-logloss:0.67786
# [65]	eval-logloss:0.67759
# [66]	eval-logloss:0.67734
# [67]	eval-logloss:0.67721
# [68]	eval-logloss:0.67735
# [69]	eval-logloss:0.67745
# [70]	eval-logloss:0.67744
# [71]	eval-logloss:0.67732
# [72]	eval-logloss:0.67740
# [73]	eval-logloss:0.67740
# [74]	eval-logloss:0.67751
# [75]	eval-logloss:0.67738
# [76]	eval-logloss:0.67712
# [77]	eval-logloss:0.67695
# [78]	eval-logloss:0.67702
# [79]	eval-logloss:0.67704
# [80]	eval-logloss:0.67686
# [81]	eval-logloss:0.67692
# [82]	eval-logloss:0.67718
# [83]	eval-logloss:0.67712
# [84]	eval-logloss:0.67707
# [85]	eval-logloss:0.67710
# [86]	eval-logloss:0.67685
# [87]	eval-logloss:0.67686
# [88]	eval-logloss:0.67683
# [89]	eval-logloss:0.67708
# [90]	eval-logloss:0.67691
# [91]	eval-logloss:0.67695
# [92]	eval-logloss:0.67688
# [93]	eval-logloss:0.67670
# [94]	eval-logloss:0.67641
# [95]	eval-logloss:0.67635
# [96]	eval-logloss:0.67652
# [97]	eval-logloss:0.67672
# [98]	eval-logloss:0.67705
# [99]	eval-logloss:0.67702
# [I 2023-11-09 16:29:47,200] Trial 47 finished with value: 0.6770152757515566 and parameters: {'max_depth': 3, 'eta': 0.08276302225974679, 'subsample': 0.7715947571923849, 'colsample_bytree': 0.567425372348243}. Best is trial 43 with value: 0.6851802125792505.

# %%
print('Best trial:')
trial = study.best_trial
print(f'Accuracy: {trial.value}')
print('Best hyperparameters: {}'.format(trial.params))

# %% [markdown]
# # Final Fastball Model

# %%
# Ensure trial is the best trial from the study
best_trial = study.best_trial

# Set parameters
final_parameters = {
    'max_depth': best_trial.params['max_depth'],
    'eta': best_trial.params['eta'],
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'subsample': best_trial.params['subsample'],
    'colsample_bytree': best_trial.params['colsample_bytree'],
}

# Prepare the data
dtrain = xgb.DMatrix(x_train, label=y_train)
# Optionally, prepare a validation set
#dval = xgb.DMatrix(x_val, label=y_val)

# Train the final model
# Optionally, include early stopping
# final_model = xgb.train(final_parameters, dtrain, early_stopping_rounds=10, evals=[(dval, 'eval')])
final_model = xgb.train(final_parameters, dtrain)

# %%
# Generate predictions
y_pred = final_model.predict(dtest)
y_pred_binary = [1 if p >= 0.5 else 0 for p in y_pred]

# Calculate Accuracy
accuracy = accuracy_score(y_test, y_pred_binary)
print(f"Accuracy: {accuracy}")

# Calculate Log Loss
logloss = log_loss(y_test, y_pred)
print(f"Log Loss: {logloss}")

# %%
importance = final_model.get_score(importance_type='gain')
# Visualizing the feature importances
xgb.plot_importance(importance)
plt.show()

# %%
# Convert predicted probabilities to binary predictions
y_pred_binary = [1 if p >= 0.5 else 0 for p in y_pred]

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred_binary)

# Plot the confusion matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Flyball', 'Flyball'], yticklabels=['Not Flyball', 'Flyball'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# ## Testing Data Set Predictions

# %%
testing_data.columns

# %%
predictions = xgb.DMatrix(testing_data, label=testing_label)

# %%
y_pred = final_model.predict(predictions)

# %%
testing_identifiers['xfb'] = y_pred

# %%
testing_identifiers.to_csv("Y:/departments/research_and_development/baseball_operations/clayton_goodiez/csv/fb_2022&3_xfb.csv")

# %% [markdown]
# # Offspeed Model

# %%
off = offspeed_data.drop(['description', 'events', 'game_pk', 'game_date', 'des', 'pitch_type_dict',
                     'spin_rate_deprecated', 'break_angle_deprecated', 'break_length_deprecated', 'game_type', 'home_team',
                     'away_team', 'type', 'bb_type', 'inning_topbot', 'hc_x', 'hc_y', 'tfs_deprecated', 'tfs_zulu_deprecated',
                     'hit_distance_sc', 'launch_speed', 'launch_angle', 'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle',
                     'woba_value', 'woba_denom', 'babip_value', 'iso_value', 'launch_speed_angle', 'pitch_name', 'home_score', 'away_score',
                     'bat_score', 'fld_score', 'post_away_score', 'post_home_score', 'post_bat_score', 'post_fld_score',
                      'if_fielding_alignment', 'of_fielding_alignment', 'delta_home_win_exp', 'delta_run_exp',
                      'player_name', 'hit_location', 'umpire', 'sv_id', 'spin_dir', 
                      'pitch_type', 'fielder_2.1', 'pitcher.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8', 
                      'fielder_9', 'batter', 'pitcher', 'on_3b', 'on_2b', 'on_1b', 'game_year', 'outs_when_up', 'pitch_number',  
                      'at_bat_number', 'inning', 'fielder_2', 'sz_top', 'sz_bot',
                      #removed these columns because of collinearity
                      'release_pos_z',  'effective_speed', 'release_pos_y', 'vy0', 'vx0', 'ax', 'release_extension', 'spin_axis', 'release_spin_rate',
                      'pfx_z', 'ay', 'p_throws', 'az', 'avg_velo', 'avg_hmov', 'avg_vmov', 'pfx_x', 'Unnamed: 0', 'release_pos_x', 'balls', 
                        'total_movement', 'vmov_diff', 'hmov_diff', 'velo_diff', 'vz0', 'release_speed'
                      #'release_spin_rate', 'p_throws', 'spin_axis', 'zone',
                      #removed these columns because they are not useful
                      ], axis=1).copy()

# %%
x2 = off.drop(['is_strike'], axis=1).copy()
y2 = off['is_strike'].copy()

# %%
len(x2)

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x2, y2, test_size=0.2, random_state=42) # split data

# %%
dtrain1 = xgb.DMatrix(x_train1, label=y_train1)
dtest1 = xgb.DMatrix(x_test1, label=y_test1)

params1 = {
    'max_depth': 6,
    'eta': 0.3,
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'subsample': 0.9,
    'colsample_bytree': 1
}

# Initial Model
model2 = xgb.train(params1, dtrain1)

# %%
print(f"Unique labels in y_test1: {np.unique(y_test1)}")
print(f"Unique labels in y_train1: {np.unique(y_train1)}")

# %%
# Generate predictions
y_pred1 = model2.predict(dtest1)
y_pred_binary1 = [1 if p >= 0.5 else 0 for p in y_pred1]

# Calculate Accuracy
accuracy = accuracy_score(y_test1, y_pred_binary1)
print(f"Accuracy: {accuracy}")

# Calculate Log Loss
logloss = log_loss(y_test1, y_pred1)
print(f"Log Loss: {logloss}")

# %%
#Use an objective function to find the best parameters
def objectives(trial):
    dtrain1 = xgb.DMatrix(x_train1, label=y_train1)
    dtest1 = xgb.DMatrix(x_test1, label=y_test1)
    
    param1 = {
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'eta': trial.suggest_float('eta', 0.01, 0.3),
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'subsample': trial.suggest_float('subsample', 0.6, 0.9),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1),
    }

    model2 = xgb.train(param1, dtrain1)
    y_pred1= model2.predict(dtest1)
    y_pred_binary1 = [1 if p >= 0.5 else 0 for p in y_pred1]
    accuracy = accuracy_score(y_test1, y_pred_binary1)
    return accuracy

# %%
#create an optuna study and specifcy the the direction of the optimization
study = optuna.create_study(direction='maximize')
study.optimize(objectives, n_trials=100)

# %%
print('Best trial:')
trial = study.best_trial
print(f'Accuracy: {trial.value}')
print('Best hyperparameters: {}'.format(trial.params))

# %%
# Ensure trial is the best trial from the study
best_trial1 = study.best_trial

# Set parameters
final_parameters1 = {
    'max_depth': best_trial.params['max_depth'],
    'eta': best_trial.params['eta'],
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'subsample': best_trial.params['subsample'],
    'colsample_bytree': best_trial.params['colsample_bytree'],
}

# Prepare the data
dtrain = xgb.DMatrix(x_train1, label=y_train1)
# Optionally, prepare a validation set
#dval = xgb.DMatrix(x_val, label=y_val)

# Train the final model
# Optionally, include early stopping
# final_model = xgb.train(final_parameters, dtrain, early_stopping_rounds=10, evals=[(dval, 'eval')])
final_model1 = xgb.train(final_parameters1, dtrain1)

# %%
# Generate predictions
y_pred1 = final_model1.predict(dtest1)
y_pred_binary1 = [1 if p >= 0.5 else 0 for p in y_pred1]

# Calculate Accuracy
accuracy = accuracy_score(y_test1, y_pred_binary1)
print(f"Accuracy: {accuracy}")

# Calculate Log Loss
logloss = log_loss(y_test1, y_pred1)
print(f"Log Loss: {logloss}")

# %%
importance1 = final_model1.get_score(importance_type='gain')
# Visualizing the feature importances
xgb.plot_importance(importance1)
plt.show()

# %% [markdown]
# # Predict 2023 data

# %%
heaters_2023 = df[df['pitch_type_dict'] == 1].copy()
offspeed_2023 = df[df['pitch_type_dict'] == 2].copy()

# %%
# Select only the features you used for training the models
features = ['zone', 'stand', 'strikes', 'plate_x', 'plate_z',  'likely_strike']  # Replace these with your actual features

# Convert DataFrame to DMatrix
dmatrix_heaters_2023 = xgb.DMatrix(heaters_2023[features])
dmatrix_offspeed_2023 = xgb.DMatrix(offspeed_2023[features])

# Make predictions
heaters_2023['prediction'] = final_model.predict(dmatrix_heaters_2023)
offspeed_2023['prediction'] = final_model1.predict(dmatrix_offspeed_2023)

# %%
complete = pd.concat([heaters_2023, offspeed_2023], axis=0)
complete['probability_added'] = 0

# %%
# Correct the conditions and assignment for 'probability_added'
condition1 = (complete['likely_strike'] == 0) & (complete['is_strike'] == 1)
complete.loc[condition1, 'probability_added'] = 1 - complete.loc[condition1, 'prediction']

condition2 = (complete['likely_strike'] == 1) & (complete['is_strike'] == 0)
complete.loc[condition2, 'probability_added'] = -0 + complete.loc[condition2, 'prediction']

# %%
len(condition2)

# %%
players = pd.read_csv('players_query.csv')

# %%
completed = complete.merge(players, left_on='fielder_2', right_on='mlb_id', how='left')

# %%
strike_probs = completed.loc[completed['probability_added'] != 0].copy()

# %%
strike_probs.head()

# %% [markdown]
# ### Catcher Evaluation

# %%
# Set the display options to show all rows
pd.set_option('display.max_rows', None)

result = strike_probs.groupby('mlb_name').agg({'probability_added': 'sum'}).sort_values(by='probability_added', ascending=False)
print(result)

# Reset the display options to default
pd.reset_option('display.max_rows')

# %%
strike_probs['framing_runs'] = (strike_probs['deltaRE'] * -1) * strike_probs['probability_added'].abs()

# %% [markdown]
# ## Initial Situational Framing Runs Leaderboard

# %%
# Set the display options to show all rows
pd.set_option('display.max_rows', None)

result = strike_probs.groupby('mlb_name').agg({'framing_runs': 'sum'}).sort_values(by='framing_runs', ascending=False)
print(result)

# Reset the display options to default
pd.reset_option('display.max_rows')

# %%
strike_probs.drop(['Unnamed: 0', 'Unnamed: 1'], axis=1, inplace=True)

# %%
strike_probs.to_csv('strike_probs.csv')

# %% [markdown]
# ### Get out meaningless strikes that have nothing to do with framing

# %%
likely = strike_probs.query('(prediction < .85)')

# %%
# Set the display options to show all rows
pd.set_option('display.max_rows', None)

result = likely.groupby('mlb_name').agg({'framing_runs': 'sum'}).sort_values(by='framing_runs', ascending=False)
print(result)

# %% [markdown]
# ###  I think that this is the best leaderboard. Filters out the gimme pitches
