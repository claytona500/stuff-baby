# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import optuna
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, log_loss
import xgboost as xgb
import seaborn as sns

# %%
data = pd.read_csv("Y:/departments/research_and_development/baseball_operations/clayton_goodiez/csv/2021_data.csv")
data_2022 = pd.read_csv("Y:/departments/research_and_development/baseball_operations/clayton_goodiez/csv/2022_data.csv")
data_2023 = pd.read_csv("Y:/departments/research_and_development/baseball_operations/clayton_goodiez/csv/2023_MLB_Seaspm.csv")
height_df = pd.read_csv("Y:/departments/research_and_development/baseball_operations/clayton_goodiez/csv/player_heights.csv")

# %%
testing_data = pd.concat([data_2022, data_2023], axis=0)

# %%
testing_data['description'].unique()
# Out:
# array(['hit_into_play', 'ball', 'foul_bunt', 'blocked_ball',
#        'swinging_strike', 'foul', 'called_strike', 'foul_tip',
#        'hit_by_pitch', 'swinging_strike_blocked', 'missed_bunt',
#        'pitchout', 'bunt_foul_tip', 'unknown_strike'], dtype=object)

# %%
def preprocess_data(df, height_df):
    """
    This function takes a DataFrame and applies several preprocessing steps to it.
    """
    # Define a function to condense pitch types
    def condense_pitch_type(pitch_type):
        if pitch_type == "FF":
            return "FF"
        elif pitch_type == "FT":
            return "SI"
        elif pitch_type == "FC":
            return "CT"
        elif pitch_type in ["SL", "ST", "SV"]:
            return "SL"
        elif pitch_type in ["CH", "FS"]:
            return "CH"
        elif pitch_type in ["CU", "KC", "CS"]:
            return "CB"
        elif pitch_type == "SI":
            return "SI"
        elif pitch_type == "KN":
            return "KN"
        else:
            return "FAHCK"
    # Define a function to determine if the pitch resulted in a swing
    def is_swing(description):
        return 1 if description in ["swinging_strike", "swinging_strike_blocked", 
                                "missed_bunt", "swinging_pitchout", 
                                "foul_tip", "foul_bunt", "foul", 
                                "foul_pitchout", "hit_into_play", 
                                "hit_into_play_no_out", "hit_into_play_score", 
                                "pitchout_hit_into_play_score"] else 0
    
    def create_pitch_id(df):
        df['pitch_id_raw'] = (df['game_pk'].astype(str) + "_" +
                          df['batter'].astype(str) + "_" +
                          df['pitcher'].astype(str) + "_" +
                          df['pitch_number'].astype(str) + "_" +
                          df['at_bat_number'].astype(str) + "_" +
                          df['inning'].astype(str))
        return df

    #create a function for whiffs
    def whiff(description):
        return 1 if description in ["swinging_strike", "swinging_strike_blocked", "missed_bunt", "swinging_pitchout"] else 0
    
    df['pitch_type_condensed'] = df['pitch_type'].apply(condense_pitch_type)

    # Calculate 'release_pos_y'
    df['release_pos_y'] = 60.5 - df['release_extension']


    df['swing'] = df['description'].apply(is_swing)
    df['whiff'] = df['description'].apply(whiff)
    # Create 'pitch_id_raw'
    df = create_pitch_id(df)

    dfs = df.merge(height_df[['id', 'height_numeric']], how='left', left_on='pitcher', right_on='id')
    # Return the preprocessed DataFrame
    return dfs

# %%
# Apply the function to the 'pitch_type' column
data_processed = preprocess_data(data, height_df)# Use the query method to filter rows where 'swing' is 1 and 'pitch_type_condensed' is 'FF', 'SI', or 'CT'
training_data = data_processed.query('swing == 1')
testing_data_processed = preprocess_data(testing_data, height_df)

# %%
fastball_training = training_data.query('pitch_type_condensed in ("FF", "SI", "CT")')
fastball_testing = testing_data_processed.query('pitch_type_condensed in ("FF", "SI", "CT")')
breaking_ball = training_data.query('pitch_type_condensed in ("SL", "CB")')
breaking_ball_testing = testing_data_processed.query('pitch_type_condensed in ("SL", "CB")')

# %% [markdown]
# # Fastball Model First

# %%
# Now, separate features and identifiers
training_identifiers = fastball_training[['pitch_id_raw']]
testing_identifiers = fastball_testing[['pitch_id_raw']]
training_features = fastball_training.drop(columns=[
    'description', 'events', 'game_pk', 'game_date', 'des', 'zone', 'stand', 'p_throws',
    'spin_rate_deprecated', 'break_angle_deprecated', 'break_length_deprecated', 
    'game_type', 'home_team', 'away_team', 'type', 'bb_type', 'inning_topbot', 
    'hc_x', 'hc_y', 'tfs_deprecated', 'tfs_zulu_deprecated', 'hit_distance_sc', 
    'launch_speed', 'launch_angle', 'estimated_ba_using_speedangle', 'swing',
    'estimated_woba_using_speedangle', 'woba_value', 'woba_denom', 'babip_value', 
    'iso_value', 'launch_speed_angle', 'pitch_name', 'home_score', 'away_score', 
    'bat_score', 'fld_score', 'post_away_score', 'post_home_score', 'post_bat_score', 
    'post_fld_score', 'if_fielding_alignment', 'of_fielding_alignment', 
    'delta_home_win_exp', 'delta_run_exp', 'player_name', 'hit_location', 'umpire', 
    'sv_id', 'spin_dir', 'pitch_type', 'fielder_2.1', 'pitcher.1', 'fielder_3', 
    'fielder_4', 'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8', 'fielder_9', 
    'batter', 'pitcher', 'on_3b', 'on_2b', 'on_1b', 'game_year', 'outs_when_up', 
    'pitch_number', 'at_bat_number', 'inning', 'fielder_2', 'sz_top', 'sz_bot',
    'pitch_id_raw', 'effective_speed', 'p_throws', 'id', 'pitch_type_condensed',
    'plate_x', 'plate_z'
], axis=1)
testing_features = fastball_testing.drop(columns=[
    'description', 'events', 'game_pk', 'game_date', 'des', 'zone', 'stand', 'p_throws',
    'spin_rate_deprecated', 'break_angle_deprecated', 'break_length_deprecated', 
    'game_type', 'home_team', 'away_team', 'type', 'bb_type', 'inning_topbot', 
    'hc_x', 'hc_y', 'tfs_deprecated', 'tfs_zulu_deprecated', 'hit_distance_sc', 
    'launch_speed', 'launch_angle', 'estimated_ba_using_speedangle', 'swing',
    'estimated_woba_using_speedangle', 'woba_value', 'woba_denom', 'babip_value', 
    'iso_value', 'launch_speed_angle', 'pitch_name', 'home_score', 'away_score', 
    'bat_score', 'fld_score', 'post_away_score', 'post_home_score', 'post_bat_score', 
    'post_fld_score', 'if_fielding_alignment', 'of_fielding_alignment', 
    'delta_home_win_exp', 'delta_run_exp', 'player_name', 'hit_location', 'umpire', 
    'sv_id', 'spin_dir', 'pitch_type', 'fielder_2.1', 'pitcher.1', 'fielder_3', 
    'fielder_4', 'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8', 'fielder_9', 
    'batter', 'pitcher', 'on_3b', 'on_2b', 'on_1b', 'game_year', 'outs_when_up', 
    'pitch_number', 'at_bat_number', 'inning', 'fielder_2', 'sz_top', 'sz_bot',
    'pitch_id_raw', 'effective_speed', 'p_throws', 'id', 'pitch_type_condensed',
    'plate_x', 'plate_z', 'Unnamed: 0'
], axis=1)   # Exclude the identifier from the features

# %%
train_data = training_features.drop(['whiff'], axis=1).copy()
train_label = training_features['whiff'].copy()
testing_data = testing_features.drop(['whiff'], axis=1).copy()
testing_label = testing_features['whiff'].copy()

# %%
train_data.columns
# Out:
# Index(['release_speed', 'release_pos_x', 'release_pos_z', 'balls', 'strikes',
#        'pfx_x', 'pfx_z', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az',
#        'release_spin_rate', 'release_extension', 'release_pos_y', 'spin_axis',
#        'height_numeric'],
#       dtype='object')

# %%
testing_data.columns
# Out:
# Index(['release_speed', 'release_pos_x', 'release_pos_z', 'balls', 'strikes',
#        'pfx_x', 'pfx_z', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az',
#        'release_spin_rate', 'release_extension', 'release_pos_y', 'spin_axis',
#        'height_numeric'],
#       dtype='object')

# %%
# First split: Separate out a portion of the data as a temporary test set
x_temp, x_test, y_temp, y_test = train_test_split(
    train_data, 
    train_label, 
    test_size=0.2, 
    random_state=42
)

# Second split: Split the temporary test set into validation and test sets
x_train, x_valid, y_train, y_valid = train_test_split(
    x_temp, 
    y_temp, 
    test_size=0.25,
    random_state=42
)

# %%
y_train.value_counts()
# Out:
# whiff
# 0    97015
# 1    21827
# Name: count, dtype: int64

# %%
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test, label=y_test)
class_ratio = y_train.value_counts()[0] / y_train.value_counts()[1]
params = {
    'max_depth': 6,
    'eta': 0.1,
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'subsample': 0.9,
    'colsample_bytree': 1,
    'scale_pos_weight': class_ratio,
}

# Initial Model
model = xgb.train(params, dtrain)

# %%
# Generate predictions
y_pred = model.predict(dtest)
y_pred_binary = [1 if p >= 0.5 else 0 for p in y_pred]

# Calculate Accuracy
accuracy = accuracy_score(y_test, y_pred_binary)
print(f"Accuracy: {accuracy}")

# Calculate Log Loss
logloss = log_loss(y_test, y_pred)
print(f"Log Loss: {logloss}")
# Out:
# Accuracy: 0.671185157137448
# Log Loss: 0.6528571282644238

# %%
xgb.plot_importance(model)
plt.show()

# %%
# Convert predicted probabilities to binary predictions
y_pred_binary = [1 if p >= 0.5 else 0 for p in y_pred]

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred_binary)

# Plot the confusion matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Swing', 'Swing'], yticklabels=['No Swing', 'Swing'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# # Initial Paramater Tuning

# %%
def objective(trial):
    dtrain = xgb.DMatrix(x_train, label=y_train)
    dvalid = xgb.DMatrix(x_valid, label=y_valid)
    
    param = {
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'eta': trial.suggest_float('eta', 0.01, 0.3),
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'subsample': trial.suggest_float('subsample', 0.6, 0.9),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1),
        'scale_pos_weight': class_ratio
    }

    # Train the model with early stopping
    model = xgb.train(
        param, 
        dtrain, 
        num_boost_round=100,  # Maximum number of boosting rounds
        evals=[(dvalid, 'eval')],  # Validation set for early stopping
        early_stopping_rounds=50  # Stop if the eval metric doesn't improve for 50 rounds
    )
    
    # Predict on the validation set using the best iteration
    y_valid_pred = model.predict(dvalid)
    
    # Calculate the log loss on the validation set
    loss = log_loss(y_valid, y_valid_pred)

    return loss

# %%
#create an optuna study and specifcy the the direction of the optimization
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=1000)
# Out:
# [I 2023-11-12 12:42:53,629] A new study created in memory with name: no-name-f785f133-cae4-4f86-a8e3-de8d709d67b3
# [0]	eval-logloss:0.68894
# [1]	eval-logloss:0.67920
# [2]	eval-logloss:0.67264
# [3]	eval-logloss:0.66484
# [4]	eval-logloss:0.66158
# [5]	eval-logloss:0.65484
# [6]	eval-logloss:0.64986
# [7]	eval-logloss:0.64796
# [8]	eval-logloss:0.64322
# [9]	eval-logloss:0.63987
# [10]	eval-logloss:0.63644
# [11]	eval-logloss:0.63330
# [12]	eval-logloss:0.63033
# [13]	eval-logloss:0.62767
# [14]	eval-logloss:0.62470
# [15]	eval-logloss:0.62356
# [16]	eval-logloss:0.62215
# [17]	eval-logloss:0.61955
# [18]	eval-logloss:0.61731
# [19]	eval-logloss:0.61553
# [20]	eval-logloss:0.61500
# [21]	eval-logloss:0.61451
# [22]	eval-logloss:0.61272
# [23]	eval-logloss:0.61230
# [24]	eval-logloss:0.61063
# [25]	eval-logloss:0.61017
# [26]	eval-logloss:0.60892
# [27]	eval-logloss:0.60754
# [28]	eval-logloss:0.60694
# [29]	eval-logloss:0.60662
# [30]	eval-logloss:0.60605
# [31]	eval-logloss:0.60494
# [32]	eval-logloss:0.60425
# [33]	eval-logloss:0.60359
# [34]	eval-logloss:0.60231
# [35]	eval-logloss:0.60186
# [36]	eval-logloss:0.60153
# [37]	eval-logloss:0.60092
# [38]	eval-logloss:0.60031
# [39]	eval-logloss:0.59981
# [40]	eval-logloss:0.59933
# [41]	eval-logloss:0.59828
# [42]	eval-logloss:0.59771
# [43]	eval-logloss:0.59687
# [44]	eval-logloss:0.59643
# [45]	eval-logloss:0.59601
# [46]	eval-logloss:0.59567
# [47]	eval-logloss:0.59529
# [48]	eval-logloss:0.59488
# [49]	eval-logloss:0.59441
# [50]	eval-logloss:0.59370
# [51]	eval-logloss:0.59319
# [52]	eval-logloss:0.59235
# [53]	eval-logloss:0.59229
# [54]	eval-logloss:0.59185
# [55]	eval-logloss:0.59126
# [56]	eval-logloss:0.59025
# [57]	eval-logloss:0.58998
# [58]	eval-logloss:0.58976
# [59]	eval-logloss:0.58955
# [60]	eval-logloss:0.58899
# [61]	eval-logloss:0.58874
# [62]	eval-logloss:0.58830
# [63]	eval-logloss:0.58822
# [64]	eval-logloss:0.58754
# [65]	eval-logloss:0.58728
# [66]	eval-logloss:0.58662
# [67]	eval-logloss:0.58676
# [68]	eval-logloss:0.58643
# [69]	eval-logloss:0.58609
# [70]	eval-logloss:0.58578
# [71]	eval-logloss:0.58558
# [72]	eval-logloss:0.58534
# [73]	eval-logloss:0.58471
# [74]	eval-logloss:0.58440
# [75]	eval-logloss:0.58372
# [76]	eval-logloss:0.58352
# [77]	eval-logloss:0.58288
# [78]	eval-logloss:0.58227
# [79]	eval-logloss:0.58216
# [80]	eval-logloss:0.58191
# [81]	eval-logloss:0.58149
# [82]	eval-logloss:0.58124
# [83]	eval-logloss:0.58107
# [84]	eval-logloss:0.58041
# [85]	eval-logloss:0.57972
# [86]	eval-logloss:0.57942
# [87]	eval-logloss:0.57917
# [88]	eval-logloss:0.57907
# [89]	eval-logloss:0.57877
# [90]	eval-logloss:0.57858
# [91]	eval-logloss:0.57778
# [92]	eval-logloss:0.57725
# [93]	eval-logloss:0.57703
# [94]	eval-logloss:0.57660
# [95]	eval-logloss:0.57651
# [96]	eval-logloss:0.57601
# [97]	eval-logloss:0.57585
# [98]	eval-logloss:0.57564
# [99]	eval-logloss:0.57524
# [I 2023-11-12 12:42:59,741] Trial 0 finished with value: 0.5752372262171718 and parameters: {'max_depth': 9, 'eta': 0.09852769785131503, 'subsample': 0.6153088274521099, 'colsample_bytree': 0.6451833099262776}. Best is trial 0 with value: 0.5752372262171718.
# [0]	eval-logloss:0.68982
# [1]	eval-logloss:0.68133
# [2]	eval-logloss:0.67598
# [3]	eval-logloss:0.66887
# [4]	eval-logloss:0.66669
# [5]	eval-logloss:0.66089
# [6]	eval-logloss:0.65668
# [7]	eval-logloss:0.65510
# [8]	eval-logloss:0.65205
# [9]	eval-logloss:0.64969
# [10]	eval-logloss:0.64625
# [11]	eval-logloss:0.64275
# [12]	eval-logloss:0.63986
# [13]	eval-logloss:0.63868
# [14]	eval-logloss:0.63679
# [15]	eval-logloss:0.63563
# [16]	eval-logloss:0.63444
# [17]	eval-logloss:0.63138
# [18]	eval-logloss:0.62905
# [19]	eval-logloss:0.62705
# [20]	eval-logloss:0.62650
# [21]	eval-logloss:0.62611
# [22]	eval-logloss:0.62486
# [23]	eval-logloss:0.62419
# [24]	eval-logloss:0.62260
# [25]	eval-logloss:0.62251
# [26]	eval-logloss:0.62161
# [27]	eval-logloss:0.62034
# [28]	eval-logloss:0.61993
# [29]	eval-logloss:0.61965
# [30]	eval-logloss:0.61918
# [31]	eval-logloss:0.61829
# [32]	eval-logloss:0.61714
# [33]	eval-logloss:0.61652
# [34]	eval-logloss:0.61525
# [35]	eval-logloss:0.61459
# [36]	eval-logloss:0.61439
# [37]	eval-logloss:0.61361
# [38]	eval-logloss:0.61297
# [39]	eval-logloss:0.61263
# [40]	eval-logloss:0.61210
# [41]	eval-logloss:0.61104
# [42]	eval-logloss:0.61060
# [43]	eval-logloss:0.60978
# [44]	eval-logloss:0.60929
# [45]	eval-logloss:0.60908
# [46]	eval-logloss:0.60887
# [47]	eval-logloss:0.60865
# [48]	eval-logloss:0.60821
# [49]	eval-logloss:0.60776
# [50]	eval-logloss:0.60762
# [51]	eval-logloss:0.60695
# [52]	eval-logloss:0.60637
# [53]	eval-logloss:0.60588
# [54]	eval-logloss:0.60539
# [55]	eval-logloss:0.60498
# [56]	eval-logloss:0.60423
# [57]	eval-logloss:0.60377
# [58]	eval-logloss:0.60354
# [59]	eval-logloss:0.60349
# [60]	eval-logloss:0.60321
# [61]	eval-logloss:0.60299
# [62]	eval-logloss:0.60231
# [63]	eval-logloss:0.60214
# [64]	eval-logloss:0.60145
# [65]	eval-logloss:0.60059
# [66]	eval-logloss:0.60014
# [67]	eval-logloss:0.60017
# [68]	eval-logloss:0.59968
# [69]	eval-logloss:0.59937
# [70]	eval-logloss:0.59890
# [71]	eval-logloss:0.59879
# [72]	eval-logloss:0.59847
# [73]	eval-logloss:0.59789
# [74]	eval-logloss:0.59767
# [75]	eval-logloss:0.59750
# [76]	eval-logloss:0.59691
# [77]	eval-logloss:0.59674
# [78]	eval-logloss:0.59632
# [79]	eval-logloss:0.59579
# [80]	eval-logloss:0.59541
# [81]	eval-logloss:0.59500
# [82]	eval-logloss:0.59464
# [83]	eval-logloss:0.59453
# [84]	eval-logloss:0.59412
# [85]	eval-logloss:0.59376
# [86]	eval-logloss:0.59343
# [87]	eval-logloss:0.59308
# [88]	eval-logloss:0.59295
# [89]	eval-logloss:0.59292
# [90]	eval-logloss:0.59284
# [91]	eval-logloss:0.59224
# [92]	eval-logloss:0.59191
# [93]	eval-logloss:0.59146
# [94]	eval-logloss:0.59092
# [95]	eval-logloss:0.59079
# [96]	eval-logloss:0.59046
# [97]	eval-logloss:0.59040
# [98]	eval-logloss:0.59014
# [99]	eval-logloss:0.58978
# [I 2023-11-12 12:43:05,083] Trial 1 finished with value: 0.5897822379816541 and parameters: {'max_depth': 8, 'eta': 0.09715668191938305, 'subsample': 0.7363993039661532, 'colsample_bytree': 0.5774350346743625}. Best is trial 0 with value: 0.5752372262171718.
# [0]	eval-logloss:0.69193
# [1]	eval-logloss:0.68819
# [2]	eval-logloss:0.68634
# [3]	eval-logloss:0.68297
# [4]	eval-logloss:0.68193
# [5]	eval-logloss:0.67917
# [6]	eval-logloss:0.67692
# [7]	eval-logloss:0.67613
# [8]	eval-logloss:0.67398
# [9]	eval-logloss:0.67310
# [10]	eval-logloss:0.67159
# [11]	eval-logloss:0.67045
# [12]	eval-logloss:0.66888
# [13]	eval-logloss:0.66727
# [14]	eval-logloss:0.66599
# [15]	eval-logloss:0.66550
# [16]	eval-logloss:0.66500
# [17]	eval-logloss:0.66399
# [18]	eval-logloss:0.66296
# [19]	eval-logloss:0.66185
# [20]	eval-logloss:0.66156
# [21]	eval-logloss:0.66134
# [22]	eval-logloss:0.66078
# [23]	eval-logloss:0.66037
# [24]	eval-logloss:0.65932
# [25]	eval-logloss:0.65920
# [26]	eval-logloss:0.65834
# [27]	eval-logloss:0.65780
# [28]	eval-logloss:0.65752
# [29]	eval-logloss:0.65734
# [30]	eval-logloss:0.65705
# [31]	eval-logloss:0.65666
# [32]	eval-logloss:0.65566
# [33]	eval-logloss:0.65505
# [34]	eval-logloss:0.65429
# [35]	eval-logloss:0.65398
# [36]	eval-logloss:0.65396
# [37]	eval-logloss:0.65370
# [38]	eval-logloss:0.65352
# [39]	eval-logloss:0.65333
# [40]	eval-logloss:0.65313
# [41]	eval-logloss:0.65209
# [42]	eval-logloss:0.65125
# [43]	eval-logloss:0.65084
# [44]	eval-logloss:0.65047
# [45]	eval-logloss:0.65052
# [46]	eval-logloss:0.65036
# [47]	eval-logloss:0.65023
# [48]	eval-logloss:0.65004
# [49]	eval-logloss:0.64935
# [50]	eval-logloss:0.64905
# [51]	eval-logloss:0.64844
# [52]	eval-logloss:0.64815
# [53]	eval-logloss:0.64798
# [54]	eval-logloss:0.64783
# [55]	eval-logloss:0.64760
# [56]	eval-logloss:0.64749
# [57]	eval-logloss:0.64734
# [58]	eval-logloss:0.64710
# [59]	eval-logloss:0.64706
# [60]	eval-logloss:0.64700
# [61]	eval-logloss:0.64687
# [62]	eval-logloss:0.64644
# [63]	eval-logloss:0.64636
# [64]	eval-logloss:0.64618
# [65]	eval-logloss:0.64596
# [66]	eval-logloss:0.64560
# [67]	eval-logloss:0.64541
# [68]	eval-logloss:0.64537
# [69]	eval-logloss:0.64518
# [70]	eval-logloss:0.64463
# [71]	eval-logloss:0.64451
# [72]	eval-logloss:0.64399
# [73]	eval-logloss:0.64374
# [74]	eval-logloss:0.64351
# [75]	eval-logloss:0.64324
# [76]	eval-logloss:0.64294
# [77]	eval-logloss:0.64284
# [78]	eval-logloss:0.64266
# [79]	eval-logloss:0.64254
# [80]	eval-logloss:0.64246
# [81]	eval-logloss:0.64240
# [82]	eval-logloss:0.64217
# [83]	eval-logloss:0.64204
# [84]	eval-logloss:0.64173
# [85]	eval-logloss:0.64132
# [86]	eval-logloss:0.64114
# [87]	eval-logloss:0.64099
# [88]	eval-logloss:0.64084
# [89]	eval-logloss:0.64077
# [90]	eval-logloss:0.64061
# [91]	eval-logloss:0.64028
# [92]	eval-logloss:0.64013
# [93]	eval-logloss:0.63999
# [94]	eval-logloss:0.63975
# [95]	eval-logloss:0.63973
# [96]	eval-logloss:0.63954
# [97]	eval-logloss:0.63958
# [98]	eval-logloss:0.63952
# [99]	eval-logloss:0.63936
# [I 2023-11-12 12:43:07,708] Trial 2 finished with value: 0.6393638085195172 and parameters: {'max_depth': 3, 'eta': 0.09151970333703169, 'subsample': 0.8338115145357339, 'colsample_bytree': 0.6187767228370034}. Best is trial 0 with value: 0.5752372262171718.
# [0]	eval-logloss:0.68918
# [1]	eval-logloss:0.67780
# [2]	eval-logloss:0.67221
# [3]	eval-logloss:0.66467
# [4]	eval-logloss:0.66286
# [5]	eval-logloss:0.65733
# [6]	eval-logloss:0.65384
# [7]	eval-logloss:0.65239
# [8]	eval-logloss:0.64954
# [9]	eval-logloss:0.64841
# [10]	eval-logloss:0.64715
# [11]	eval-logloss:0.64563
# [12]	eval-logloss:0.64504
# [13]	eval-logloss:0.64458
# [14]	eval-logloss:0.64296
# [15]	eval-logloss:0.64211
# [16]	eval-logloss:0.64195
# [17]	eval-logloss:0.64055
# [18]	eval-logloss:0.63955
# [19]	eval-logloss:0.63895
# [20]	eval-logloss:0.63852
# [21]	eval-logloss:0.63847
# [22]	eval-logloss:0.63783
# [23]	eval-logloss:0.63763
# [24]	eval-logloss:0.63639
# [25]	eval-logloss:0.63648
# [26]	eval-logloss:0.63595
# [27]	eval-logloss:0.63561
# [28]	eval-logloss:0.63489
# [29]	eval-logloss:0.63494
# [30]	eval-logloss:0.63441
# [31]	eval-logloss:0.63411
# [32]	eval-logloss:0.63292
# [33]	eval-logloss:0.63217
# [34]	eval-logloss:0.63201
# [35]	eval-logloss:0.63216
# [36]	eval-logloss:0.63244
# [37]	eval-logloss:0.63168
# [38]	eval-logloss:0.63168
# [39]	eval-logloss:0.63131
# [40]	eval-logloss:0.63107
# [41]	eval-logloss:0.63037
# [42]	eval-logloss:0.62974
# [43]	eval-logloss:0.62964
# [44]	eval-logloss:0.62911
# [45]	eval-logloss:0.62939
# [46]	eval-logloss:0.62915
# [47]	eval-logloss:0.62911
# [48]	eval-logloss:0.62921
# [49]	eval-logloss:0.62843
# [50]	eval-logloss:0.62815
# [51]	eval-logloss:0.62821
# [52]	eval-logloss:0.62737
# [53]	eval-logloss:0.62709
# [54]	eval-logloss:0.62705
# [55]	eval-logloss:0.62682
# [56]	eval-logloss:0.62712
# [57]	eval-logloss:0.62686
# [58]	eval-logloss:0.62698
# [59]	eval-logloss:0.62746
# [60]	eval-logloss:0.62709
# [61]	eval-logloss:0.62679
# [62]	eval-logloss:0.62625
# [63]	eval-logloss:0.62595
# [64]	eval-logloss:0.62540
# [65]	eval-logloss:0.62490
# [66]	eval-logloss:0.62420
# [67]	eval-logloss:0.62427
# [68]	eval-logloss:0.62421
# [69]	eval-logloss:0.62407
# [70]	eval-logloss:0.62390
# [71]	eval-logloss:0.62409
# [72]	eval-logloss:0.62340
# [73]	eval-logloss:0.62343
# [74]	eval-logloss:0.62313
# [75]	eval-logloss:0.62306
# [76]	eval-logloss:0.62248
# [77]	eval-logloss:0.62251
# [78]	eval-logloss:0.62264
# [79]	eval-logloss:0.62205
# [80]	eval-logloss:0.62181
# [81]	eval-logloss:0.62217
# [82]	eval-logloss:0.62175
# [83]	eval-logloss:0.62135
# [84]	eval-logloss:0.62084
# [85]	eval-logloss:0.62034
# [86]	eval-logloss:0.62013
# [87]	eval-logloss:0.61987
# [88]	eval-logloss:0.62022
# [89]	eval-logloss:0.62028
# [90]	eval-logloss:0.62001
# [91]	eval-logloss:0.61920
# [92]	eval-logloss:0.61872
# [93]	eval-logloss:0.61835
# [94]	eval-logloss:0.61810
# [95]	eval-logloss:0.61854
# [96]	eval-logloss:0.61832
# [97]	eval-logloss:0.61866
# [98]	eval-logloss:0.61850
# [99]	eval-logloss:0.61795
# [I 2023-11-12 12:43:10,750] Trial 3 finished with value: 0.6179472621625423 and parameters: {'max_depth': 4, 'eta': 0.24815700639796517, 'subsample': 0.7793731004621625, 'colsample_bytree': 0.6151762206901996}. Best is trial 0 with value: 0.5752372262171718.
# [0]	eval-logloss:0.67985
# [1]	eval-logloss:0.67218
# [2]	eval-logloss:0.66445
# [3]	eval-logloss:0.65997
# [4]	eval-logloss:0.65613
# [5]	eval-logloss:0.65317
# [6]	eval-logloss:0.65130
# [7]	eval-logloss:0.64959
# [8]	eval-logloss:0.64738
# [9]	eval-logloss:0.64644
# [10]	eval-logloss:0.64574
# [11]	eval-logloss:0.64481
# [12]	eval-logloss:0.64354
# [13]	eval-logloss:0.64156
# [14]	eval-logloss:0.64007
# [15]	eval-logloss:0.63931
# [16]	eval-logloss:0.63900
# [17]	eval-logloss:0.63789
# [18]	eval-logloss:0.63641
# [19]	eval-logloss:0.63618
# [20]	eval-logloss:0.63575
# [21]	eval-logloss:0.63581
# [22]	eval-logloss:0.63517
# [23]	eval-logloss:0.63459
# [24]	eval-logloss:0.63384
# [25]	eval-logloss:0.63396
# [26]	eval-logloss:0.63336
# [27]	eval-logloss:0.63286
# [28]	eval-logloss:0.63206
# [29]	eval-logloss:0.63190
# [30]	eval-logloss:0.63120
# [31]	eval-logloss:0.63048
# [32]	eval-logloss:0.63006
# [33]	eval-logloss:0.62963
# [34]	eval-logloss:0.62933
# [35]	eval-logloss:0.62913
# [36]	eval-logloss:0.62924
# [37]	eval-logloss:0.62830
# [38]	eval-logloss:0.62821
# [39]	eval-logloss:0.62746
# [40]	eval-logloss:0.62721
# [41]	eval-logloss:0.62634
# [42]	eval-logloss:0.62569
# [43]	eval-logloss:0.62563
# [44]	eval-logloss:0.62516
# [45]	eval-logloss:0.62529
# [46]	eval-logloss:0.62532
# [47]	eval-logloss:0.62477
# [48]	eval-logloss:0.62458
# [49]	eval-logloss:0.62381
# [50]	eval-logloss:0.62331
# [51]	eval-logloss:0.62315
# [52]	eval-logloss:0.62295
# [53]	eval-logloss:0.62278
# [54]	eval-logloss:0.62245
# [55]	eval-logloss:0.62225
# [56]	eval-logloss:0.62202
# [57]	eval-logloss:0.62195
# [58]	eval-logloss:0.62189
# [59]	eval-logloss:0.62184
# [60]	eval-logloss:0.62114
# [61]	eval-logloss:0.62080
# [62]	eval-logloss:0.62052
# [63]	eval-logloss:0.62041
# [64]	eval-logloss:0.62018
# [65]	eval-logloss:0.61974
# [66]	eval-logloss:0.61931
# [67]	eval-logloss:0.61927
# [68]	eval-logloss:0.61906
# [69]	eval-logloss:0.61876
# [70]	eval-logloss:0.61849
# [71]	eval-logloss:0.61874
# [72]	eval-logloss:0.61824
# [73]	eval-logloss:0.61815
# [74]	eval-logloss:0.61779
# [75]	eval-logloss:0.61772
# [76]	eval-logloss:0.61760
# [77]	eval-logloss:0.61761
# [78]	eval-logloss:0.61758
# [79]	eval-logloss:0.61727
# [80]	eval-logloss:0.61697
# [81]	eval-logloss:0.61709
# [82]	eval-logloss:0.61697
# [83]	eval-logloss:0.61688
# [84]	eval-logloss:0.61669
# [85]	eval-logloss:0.61566
# [86]	eval-logloss:0.61551
# [87]	eval-logloss:0.61518
# [88]	eval-logloss:0.61484
# [89]	eval-logloss:0.61479
# [90]	eval-logloss:0.61438
# [91]	eval-logloss:0.61392
# [92]	eval-logloss:0.61367
# [93]	eval-logloss:0.61339
# [94]	eval-logloss:0.61293
# [95]	eval-logloss:0.61315
# [96]	eval-logloss:0.61298
# [97]	eval-logloss:0.61305
# [98]	eval-logloss:0.61308
# [99]	eval-logloss:0.61295
# [I 2023-11-12 12:43:13,797] Trial 4 finished with value: 0.6129488727147261 and parameters: {'max_depth': 5, 'eta': 0.2058640104649249, 'subsample': 0.8191800638835232, 'colsample_bytree': 0.7274396340220874}. Best is trial 0 with value: 0.5752372262171718.
# [0]	eval-logloss:0.69130
# [1]	eval-logloss:0.68661
# [2]	eval-logloss:0.68163
# [3]	eval-logloss:0.67751
# [4]	eval-logloss:0.67593
# [5]	eval-logloss:0.67214
# [6]	eval-logloss:0.66919
# [7]	eval-logloss:0.66806
# [8]	eval-logloss:0.66515
# [9]	eval-logloss:0.66227
# [10]	eval-logloss:0.65969
# [11]	eval-logloss:0.65740
# [12]	eval-logloss:0.65560
# [13]	eval-logloss:0.65373
# [14]	eval-logloss:0.65204
# [15]	eval-logloss:0.65111
# [16]	eval-logloss:0.65019
# [17]	eval-logloss:0.64817
# [18]	eval-logloss:0.64652
# [19]	eval-logloss:0.64537
# [20]	eval-logloss:0.64486
# [21]	eval-logloss:0.64470
# [22]	eval-logloss:0.64302
# [23]	eval-logloss:0.64275
# [24]	eval-logloss:0.64135
# [25]	eval-logloss:0.64110
# [26]	eval-logloss:0.64030
# [27]	eval-logloss:0.63923
# [28]	eval-logloss:0.63885
# [29]	eval-logloss:0.63875
# [30]	eval-logloss:0.63831
# [31]	eval-logloss:0.63720
# [32]	eval-logloss:0.63639
# [33]	eval-logloss:0.63538
# [34]	eval-logloss:0.63458
# [35]	eval-logloss:0.63440
# [36]	eval-logloss:0.63394
# [37]	eval-logloss:0.63357
# [38]	eval-logloss:0.63297
# [39]	eval-logloss:0.63206
# [40]	eval-logloss:0.63168
# [41]	eval-logloss:0.63102
# [42]	eval-logloss:0.63043
# [43]	eval-logloss:0.62990
# [44]	eval-logloss:0.62953
# [45]	eval-logloss:0.62941
# [46]	eval-logloss:0.62940
# [47]	eval-logloss:0.62914
# [48]	eval-logloss:0.62884
# [49]	eval-logloss:0.62823
# [50]	eval-logloss:0.62777
# [51]	eval-logloss:0.62737
# [52]	eval-logloss:0.62684
# [53]	eval-logloss:0.62673
# [54]	eval-logloss:0.62672
# [55]	eval-logloss:0.62653
# [56]	eval-logloss:0.62576
# [57]	eval-logloss:0.62547
# [58]	eval-logloss:0.62511
# [59]	eval-logloss:0.62510
# [60]	eval-logloss:0.62493
# [61]	eval-logloss:0.62484
# [62]	eval-logloss:0.62443
# [63]	eval-logloss:0.62434
# [64]	eval-logloss:0.62397
# [65]	eval-logloss:0.62390
# [66]	eval-logloss:0.62330
# [67]	eval-logloss:0.62334
# [68]	eval-logloss:0.62319
# [69]	eval-logloss:0.62297
# [70]	eval-logloss:0.62265
# [71]	eval-logloss:0.62230
# [72]	eval-logloss:0.62211
# [73]	eval-logloss:0.62185
# [74]	eval-logloss:0.62165
# [75]	eval-logloss:0.62130
# [76]	eval-logloss:0.62099
# [77]	eval-logloss:0.62069
# [78]	eval-logloss:0.62046
# [79]	eval-logloss:0.62019
# [80]	eval-logloss:0.62000
# [81]	eval-logloss:0.61981
# [82]	eval-logloss:0.61953
# [83]	eval-logloss:0.61930

# %%
print('Best trial:')
trial = study.best_trial
print(f'Accuracy: {trial.value}')
print('Best hyperparameters: {}'.format(trial.params))

# %% [markdown]
# # Final Fastball Model

# %%
# Ensure trial is the best trial from the study
best_trial = study.best_trial

# Set parameters
final_parameters = {
    'max_depth': best_trial.params['max_depth'],
    'eta': best_trial.params['eta'],
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'subsample': best_trial.params['subsample'],
    'colsample_bytree': best_trial.params['colsample_bytree'],
    'scale_pos_weight': class_ratio
}

# Prepare the data
dtrain = xgb.DMatrix(x_train, label=y_train)
# Optionally, prepare a validation set
#dval = xgb.DMatrix(x_val, label=y_val)

# Train the final model
# Optionally, include early stopping
# final_model = xgb.train(final_parameters, dtrain, early_stopping_rounds=10, evals=[(dval, 'eval')])
final_model = xgb.train(final_parameters, dtrain)

# %%
# Generate predictions
y_pred = final_model.predict(dtest)
y_pred_binary = [1 if p >= 0.5 else 0 for p in y_pred]

# Calculate Accuracy
accuracy = accuracy_score(y_test, y_pred_binary)
print(f"Accuracy: {accuracy}")

# Calculate Log Loss
logloss = log_loss(y_test, y_pred)
print(f"Log Loss: {logloss}")

# Calculate F1 Score
f1 = f1_score(y_test, y_pred_binary)
print(f"F1 Score: {f1}")

# %%
importance = final_model.get_score(importance_type='gain')
# Visualizing the feature importances
xgb.plot_importance(importance)
plt.show()

# %%
# Convert predicted probabilities to binary predictions
y_pred_binary = [1 if p >= 0.5 else 0 for p in y_pred]

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred_binary)

# Plot the confusion matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Swing', 'Swing'], yticklabels=['No Swing', 'Swing'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# ## Testing Data Set Predictions

# %%
testing_data.columns

# %%
predictions = xgb.DMatrix(testing_data, label=testing_label)

# %%
y_pred = final_model.predict(predictions)

# %%
testing_identifiers['xwhiff'] = y_pred

# %%
testing_identifiers.head()

# %%
testing_identifiers.to_csv("Y:/departments/research_and_development/baseball_operations/clayton_goodiez/csv/whiff_2022&3_xwhiff.csv")
